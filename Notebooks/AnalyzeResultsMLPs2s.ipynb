# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Wind.Results import DBResults
from Wind.Private.DBConfig import mongoremote,mongolocal,mongolocaltest
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# Retrieves the results of the query

# %%
query = {"experiment": "MLP_s2s_2","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %% [markdown]
# Samples 5% and plots a distribution plot of the sum of the R² of all the hours

# %%
results.sample(.05)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum', figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4ba3f3377ec3> in <module>
# ----> 1 results.sample(.05)
#       2 results.selected_size()
#       3
#       4 results.plot_distplot(seaborn=True, notebook=True, summary='sum', figsize=(10,10))
#
# NameError: name 'results' is not defined

# %%
results.sample(.05)
results.selected_size()
results.plot_hours_boxplot(figsize=(12,6))
# Out:
# 6334

# %%
results.sample(.05)
results.selected_size()
results.plot_densplot(figsize=(12,6))
# Out:
# 6334

# %%
query1 = {"experiment": "MLP_s2s_2","status":"done"}
query2 = {"experiment": "RNN_s2s","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results_compare(query1,query2)
results.selected_size()
# Out:
# 126692

# %%
results.sample(1)
results.selected_size()

results.plot_distplot_compare(summary='sum', compare='diff', seaborn=True, notebook=True, figsize=(10,10))
# Out:
# 126692

# %%
results.sample(0.2)
results.selected_size()
results.plot_densplot_compare(figsize=(12,6))
# Out:
# 25338
