[0, 1, 2, 3, 4, 5, 6]  [1, 12]  18
# 169306    11   48744  0.521776  0.443353  [0, 1, 2, 3, 4, 5, 6]  [1, 12]  18
# 169307    12   48744  0.490930  0.404989  [0, 1, 2, 3, 4, 5, 6]  [1, 12]  18
#
#        drop neuronsE neuronsD
# 0       0.0       64       32
# 1       0.0       64       32
# 2       0.0       64       32
# 3       0.0       64       32
# 4       0.0       64       32
# 5       0.0       64       32
# 6       0.0       64       32
# 7       0.0       64       32
# 8       0.0       64       32
# 9       0.0       64       32
# 10      0.0       64       32
# 11      0.0       64       32
# 12      0.0       64       32
# 13      0.0       64       32
# 14      0.0       64       32
# 15      0.0       64       32
# 16      0.0       64       32
# 17      0.0       64       32
# 18      0.0       64       32
# 19      0.0       64       32
# 20      0.0       64       32
# 21      0.0       64       32
# 22      0.0       64       32
# 23      0.0       64       32
# 24      0.0      160       32
# 25      0.0      160       32
# 26      0.0      160       32
# 27      0.0      160       32
# 28      0.0      160       32
# 29      0.0      160       32
# ...     ...      ...      ...
# 169278  0.4      160       96
# 169279  0.4      160       96
# 169280  0.4      160       96
# 169281  0.4      160       96
# 169282  0.4      160       96
# 169283  0.4      160       96
# 169284  0.4      160       96
# 169285  0.4      160       96
# 169286  0.4      160       96
# 169287  0.4      160       96
# 169288  0.4      160       96
# 169289  0.4      160       96
# 169290  0.4      160       96
# 169291  0.4      160       96
# 169292  0.4      160       96
# 169293  0.4      160       96
# 169294  0.4      160       96
# 169295  0.4      160       96
# 169296  0.4      160       96
# 169297  0.4      160       96
# 169298  0.4      160       96
# 169299  0.4      160       96
# 169300  0.4      160       96
# 169301  0.4      160       96
# 169302  0.4      160       96
# 169303  0.4      160       96
# 169304  0.4      160       96
# 169305  0.4      160       96
# 169306  0.4      160       96
# 169307  0.4      160       96
#
# [169308 rows x 10 columns]

# %%
plt.figure(figsize=(12,8), dpi=100)
plt.style.use('seaborn-whitegrid')
plt.xticks(rotation=90)
sns.boxplot(x='neuronsE', y='test', data=results.exp_df[results.exp_df.hour==1])
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)

# %% [markdown]
# Samples 5% and plots a distribution plot of the sum of the R² of all the hours

# %%
a=results.exp_df.groupby(['site', 'drop', 'neuronsE', 'neuronsD'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)

# %%
# plt.figure(figsize=(12,8), dpi=100)
# plt.style.use('seaborn-whitegrid')
# plt.xticks(rotation=90)
#sns.boxplot(x='neuronsD', by='dropout', y='test', data=a)
a.boxplot(by='neuronsD',figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd684bd3c88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd684e89048>],
#       dtype=object)

# %% [markdown]
# Selects the 500 best/worst results and plots in a map the sum of R² of all the hours for test and validation

# %%
a.boxplot(by='neuronsE',figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd686112898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6860ed710>],
#       dtype=object)

# %%
a.boxplot(by='drop',figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd684a27240>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6844ca240>],
#       dtype=object)
