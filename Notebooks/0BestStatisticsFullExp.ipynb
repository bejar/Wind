# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Wind.Results import DBResults
from Wind.Private.DBConfig import mongoremote,mongolocal,mongolocaltest
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Persistence

# %%
query = {"experiment": "Persistence","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.75)
results.selected_size()

results.plot_map(dset=('test'),figsize=(1200,800),cmap='Viridis')
# Out:
# 95019

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(dset=('test'),figsize=(8,6), title='Persistence', font=18, labels=['test'],save='persistence')
# Out:
# 126692
# MEAN (test)= 2.6989266365223443
# StDev (test)= 1.9511900646278684

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(10,8), title='Persistence', font=15)

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:               126692
# Model:                            GLM   Df Residuals:                   126690
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.40190
# Method:                          IRLS   Log-Likelihood:            -1.2202e+05
# Date:                Fri, 24 May 2019   Deviance:                       50917.
# Time:                        12:41:52   Pearson chi2:                 5.09e+04
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3089      0.003    105.980      0.000       0.303       0.315
# ...

# %% [markdown]
# # MLP S2S

# %%
query = {"experiment": "MLP_s2s_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
# results.sample(0.1)
# results.selected_size()

# results.plot_map(mapbox=False,dset=('test'),figsize=(1200,800))
# Out:
# 12669

# %%
results.sample(0.02)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP')
# Out:
# 2533
# MEAN (test)= 7.2136017717038525
# StDev (test)= 0.7832791010386445
# MEAN (val)= 6.918319843687974
# StDev (val)= 0.73006383048926

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, test=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:               126690
# Model:                            GLM   Df Residuals:                   126688
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13053
# Method:                          IRLS   Log-Likelihood:                -50785.
# Date:                Mon, 01 Jul 2019   Deviance:                       16537.
# Time:                        09:06:42   Pearson chi2:                 1.65e+04
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5945      0.009     62.713      0.000       0.576       0.613
# ...

# %% [markdown]
# # MLP S2S SSA

# %%
query = {"experiment": "MLP_s2s_SSA_best_sample","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
# results.sample(0.1)
# results.selected_size()

results.plot_map(mapbox=False,dset=('test'),figsize=(1200,800))

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP')
# Out:
# MEAN (test)= 7.203473612568442
# StDev (test)= 0.8243761969438772
# MEAN (val)= 6.893107438381283
# StDev (val)= 0.7697151976349699

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, test=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:               126690
# Model:                            GLM   Df Residuals:                   126688
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13053
# Method:                          IRLS   Log-Likelihood:                -50785.
# Date:                Mon, 01 Jul 2019   Deviance:                       16537.
# Time:                        09:06:42   Pearson chi2:                 1.65e+04
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5945      0.009     62.713      0.000       0.576       0.613
# ...

# %% [markdown]
# # MLP S2S RLROP

# %%
query = {"experiment": "MLP_s2s_best_sample_RLROP","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
# results.sample(0.1)
# results.selected_size()

results.plot_map(mapbox=False,dset=('test'),figsize=(1200,800))

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP')
# Out:
# MEAN (test)= 7.267192557875456
# StDev (test)= 0.828524776366585
# MEAN (val)= 6.965832417074562
# StDev (val)= 0.7739869997830877

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, test=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 1998
# Model:                            GLM   Df Residuals:                     1996
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13671
# Method:                          IRLS   Log-Likelihood:                -846.16
# Date:                Wed, 18 Sep 2019   Deviance:                       272.88
# Time:                        08:16:35   Pearson chi2:                     273.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5971      0.075      7.975      0.000       0.450       0.744
# ...

# %% [markdown]
# # MLP S2S RLROP SE

# %%
query = {"experiment": "MLP_s2s_best_sample_RLROP_SE","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
# results.plot_map(mapbox=False,dset=('test'),figsize=(1200,800))

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP')
# Out:
# MEAN (test)= 7.285738987736834
# StDev (test)= 0.793087896324824
# MEAN (val)= 6.991082709163342
# StDev (val)= 0.7340018435635078

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, test=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 1998
# Model:                            GLM   Df Residuals:                     1996
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13671
# Method:                          IRLS   Log-Likelihood:                -846.16
# Date:                Wed, 18 Sep 2019   Deviance:                       272.88
# Time:                        08:16:35   Pearson chi2:                     273.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5971      0.075      7.975      0.000       0.450       0.744
# ...

# %% [markdown]
# # MLP S2S RLROP SE 5 minutes

# %%
query = {"experiment": "MLP_s2s_best_sample_RLROP_SE_12","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
# results.plot_map(mapbox=False,dset=('test'),figsize=(1200,800))

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP')
# Out:
# MEAN (test)= 7.4055327426828566
# StDev (test)= 0.7740880181245984
# MEAN (val)= 7.090089763921962
# StDev (val)= 0.7305838086462672

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, test=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12001
# Method:                          IRLS   Log-Likelihood:                -716.74
# Date:                Thu, 26 Sep 2019   Deviance:                       239.79
# Time:                        06:46:41   Pearson chi2:                     240.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6867      0.076      9.086      0.000       0.539       0.835
# ...

# %% [markdown]
# # MLP DirReg

# %%
query = {"experiment": "MLPDir","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP Dir')
# Out:
# 2000
# MEAN (test)= 6.83149184944583
# StDev (test)= 0.8060619991779323
# MEAN (val)= 6.508647537121852
# StDev (val)= 0.7437231267516182

# %%
query = {"experiment": "MLP_s2s_2","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.0158)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP')
# Out:
# 2001
# MEAN (test)= 7.065204469990404
# StDev (test)= 0.7969691997490052
# MEAN (val)= 6.768566174879485
# StDev (val)= 0.753032842244216

# %% [markdown]
# # CNN seq2seq causal convolutions 1layer

# %%
query = {"experiment": "CNN_s2s_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.1)
results.selected_size()

results.plot_map(dset=('test'),figsize=(1200,800))
# Out:
# 12124

# %%
results.sample(0.02)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10))
# Out:
# 2533
# MEAN (test)= 7.211827710779277
# StDev (test)= 0.8045803272855585
# MEAN (val)= 6.895396913948838
# StDev (val)= 0.7517246211056048

# %%
results.sample(0.25)
results.selected_size()
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))
# Out:
# 30311

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                30311
# Model:                            GLM   Df Residuals:                    30309
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13784
# Method:                          IRLS   Log-Likelihood:                -12975.
# Date:                Mon, 22 Jul 2019   Deviance:                       4177.8
# Time:                        06:33:32   Pearson chi2:                 4.18e+03
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6444      0.020     32.665      0.000       0.606       0.683
# ...

# %% [markdown]
# # CNN seq2seq causal convolutions 1layer RLROP

# %%
query = {"experiment": "CNN_s2s_best_sample_RLROP","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
# results.plot_map(dset=('test'),figsize=(1200,800))

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10))
# Out:
# MEAN (test)= 7.193780400739695
# StDev (test)= 0.8362475902000128
# MEAN (val)= 6.88758822808187
# StDev (val)= 0.7853296442115503

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))
# Out:
# 30311

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                30311
# Model:                            GLM   Df Residuals:                    30309
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13784
# Method:                          IRLS   Log-Likelihood:                -12975.
# Date:                Mon, 22 Jul 2019   Deviance:                       4177.8
# Time:                        06:33:32   Pearson chi2:                 4.18e+03
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6444      0.020     32.665      0.000       0.606       0.683
# ...

# %% [markdown]
# # CNN seq2seq causal convolutions 1layer RLROP SE sampling

# %%
query = {"experiment": "CNN_s2s_best_sample_RLROP_SE","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
# results.plot_map(dset=('test'),figsize=(1200,800))

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10))
# Out:
# MEAN (test)= 7.214007302978093
# StDev (test)= 0.801666234189739
# MEAN (val)= 6.915065186120838
# StDev (val)= 0.7442758299315485

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                30311
# Model:                            GLM   Df Residuals:                    30309
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13784
# Method:                          IRLS   Log-Likelihood:                -12975.
# Date:                Mon, 22 Jul 2019   Deviance:                       4177.8
# Time:                        06:33:32   Pearson chi2:                 4.18e+03
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6444      0.020     32.665      0.000       0.606       0.683
# ...

# %% [markdown]
# # CNN seq2seq same padding convolutions 1layer

# %%
query = {"experiment": "CNN_s2s_same_best_sample","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
# results.sample(0.1)
# results.selected_size()

# results.plot_map(dset=('test'),figsize=(1200,800))

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10))
# Out:
# MEAN (test)= 7.234020588657179
# StDev (test)= 0.8316438548799201
# MEAN (val)= 6.918481425069118
# StDev (val)= 0.777346815839359

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))
# Out:
# 30311

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                30311
# Model:                            GLM   Df Residuals:                    30309
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13784
# Method:                          IRLS   Log-Likelihood:                -12975.
# Date:                Mon, 22 Jul 2019   Deviance:                       4177.8
# Time:                        06:33:32   Pearson chi2:                 4.18e+03
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6444      0.020     32.665      0.000       0.606       0.683
# ...

# %% [markdown]
# # CNN seq2seq causal convo 2 layers

# %%
query = {"experiment": "CNN_s2s_2l_best_sample","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test','val'), figsize=(10,10))
# Out:
# MEAN (test)= 7.215707716813604
# StDev (test)= 0.835320053751007
# MEAN (val)= 6.887651876462169
# StDev (val)= 0.7763968342371089

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 1457
# Model:                            GLM   Df Residuals:                     1455
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14084
# Method:                          IRLS   Log-Likelihood:                -638.45
# Date:                Mon, 09 Sep 2019   Deviance:                       204.92
# Time:                        14:06:03   Pearson chi2:                     205.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6065      0.088      6.928      0.000       0.435       0.778
# ...

# %% [markdown]
# # CNN seq2seq separable convo 2 layers

# %%
query = {"experiment": "CNN_s2s_sep_2l_best_sample","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test','val'), figsize=(10,10))
# Out:
# MEAN (test)= 7.321329932368642
# StDev (test)= 0.8307068080588671
# MEAN (val)= 7.005043969882863
# StDev (val)= 0.7774207060871077

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))

# %% [markdown]
# # CNN seq2seq separable convo 2 layers RLROP SE 5min

# %%
query = {"experiment": "CNN_s2s_sep_2l_best_sample_RLROP_SE_12","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test','val'), figsize=(10,10))
# Out:
# MEAN (test)= 7.150002572721634
# StDev (test)= 0.7972025175604408
# MEAN (val)= 6.855051934747882
# StDev (val)= 0.7368955788746586

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))

# %% [markdown]
# # CNN seq2seq CI convo 2 heads

# %%
query = {"experiment": "CNN_s2s_CI_2h_best_sample","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test','val'), figsize=(10,10))
# Out:
# MEAN (test)= 7.20588055440191
# StDev (test)= 0.8333150296424526
# MEAN (val)= 6.89313494217408
# StDev (val)= 0.7766073855065847

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                  186
# Model:                            GLM   Df Residuals:                      184
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14851
# Method:                          IRLS   Log-Likelihood:                -85.557
# Date:                Mon, 09 Sep 2019   Deviance:                       27.326
# Time:                        14:58:26   Pearson chi2:                     27.3
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7071      0.264      2.674      0.008       0.189       1.225
# ...

# %% [markdown]
# # MIMO RNN

# %%
query = {"experiment": "RNN_s2s","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.05)
results.selected_size()

results.plot_map(dset=('val'),figsize=(1200,800))

# %%
results.sample(1)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test'), figsize=(10,10))
# Out:
# 126692
# MEAN (test)= 6.852182196280556
# StDev (test)= 0.8167559261639322

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:               126692
# Model:                            GLM   Df Residuals:                   126690
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14593
# Method:                          IRLS   Log-Likelihood:                -57851.
# Date:                Mon, 25 Feb 2019   Deviance:                       18488.
# Time:                        10:37:07   Pearson chi2:                 1.85e+04
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6405      0.009     68.895      0.000       0.622       0.659
# ...

# %% [markdown]
# # MIMO RNN ED

# %%
query = {"experiment": "RNN_ED_s2s_2","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.05)
results.selected_size()

results.plot_map(dset=('val'),figsize=(1200,800))
# Out:
# 6334

# %%
results.sample(1)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test'), figsize=(10,10))
# Out:
# 126692
# MEAN (test)= 6.867959120943678
# StDev (test)= 0.8083999060451638

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14228
# Method:                          IRLS   Log-Likelihood:                -14061.
# Date:                Wed, 20 Feb 2019   Deviance:                       4506.3
# Time:                        07:30:30   Pearson chi2:                 4.51e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7423      0.018     40.340      0.000       0.706       0.778
# ...

# %% [markdown]
# # RNN seq2seq sample

# %%
query = {"experiment": "RNN_s2s_best_sample","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
# results.sample(0.1)
# results.selected_size()

# results.plot_map(dset=('test'),figsize=(1200,800))

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10))
# Out:
# MEAN (test)= 7.164179543699896
# StDev (test)= 0.8334796473746132
# MEAN (val)= 6.838530820611148
# StDev (val)= 0.7793312583650006

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                30311
# Model:                            GLM   Df Residuals:                    30309
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13784
# Method:                          IRLS   Log-Likelihood:                -12975.
# Date:                Mon, 22 Jul 2019   Deviance:                       4177.8
# Time:                        06:33:32   Pearson chi2:                 4.18e+03
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6444      0.020     32.665      0.000       0.606       0.683
# ...
