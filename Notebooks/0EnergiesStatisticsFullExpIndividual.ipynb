# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from Wind.Results import DBResults
from Wind.Private.DBConfig import mongoremote,mongolocal,mongolocaltest
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Persistence

# %%
query = {"experiment": "Persistence","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.1)
results.selected_size()

results.plot_map(dset=('test'),figsize=(1200,800),cmap='Viridis')
# Out:
# 12669

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(dset=('test'),figsize=(8,6), title='Persistence', font=18, labels=['test'],save='persistence')
# Out:
# 126692
# MEAN (test)= 2.6989266365223443
# StDev (test)= 1.9511900646278684

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(10,8), title='Persistence', font=15)

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:               126692
# Model:                            GLM   Df Residuals:                   126690
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.40190
# Method:                          IRLS   Log-Likelihood:            -1.2202e+05
# Date:                Fri, 24 May 2019   Deviance:                       50917.
# Time:                        12:41:52   Pearson chi2:                 5.09e+04
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3089      0.003    105.980      0.000       0.303       0.315
# validation     0.9612      0.001   1036.067      0.000       0.959       0.963
# ==============================================================================

# %% [markdown]
# # MLP Dir

# %%
query = {"experiment": "MLPDir","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()

results.plot_map(dset=('test'),figsize=(1200,800),cmap='Viridis')
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP Dir')
# Out:
# 2000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-a1a67a0df966> in <module>
#       2 results.selected_size()
#       3
# ----> 4 results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP Dir')
#
# ~/PycharmProjects/Wind/Wind/Results/DBResults.py in plot_distplot(self, summary, seaborn, notebook, dset, figsize, title, labels, font, save, saveformat)
#     732             #extra = [1, 0]
#     733         elif summary == 'sum':
# --> 734             sumtest = np.sum(self.exp_result['test'][self.selection], axis=1)
#     735             sumval = np.sum(self.exp_result['validation'][self.selection], axis=1)
#     736             #extra = [10, 0]
#
# IndexError: index 71237 is out of bounds for axis 0 with size 2000

# %%
query = {"experiment": "MLP_s2s_2","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.0158)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP')
# Out:
# 2001
# MEAN (test)= 7.065204469990404
# StDev (test)= 0.7969691997490052
# MEAN (val)= 6.768566174879485
# StDev (val)= 0.753032842244216

# %% [markdown]
# # MIMO MLP

# %%
query = {"experiment": "MLP_s2s_2","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.05)
results.selected_size()

results.plot_map(mapbox=False,dset=('test'),figsize=(1200,800))

# %%
results.sample(1)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP')
# Out:
# 126692
# MEAN (test)= 7.057314136586461
# StDev (test)= 0.8108856184679908
# MEAN (val)= 6.7715213851856335
# StDev (val)= 0.7513327170146366

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, test=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                12669
# Model:                            GLM   Df Residuals:                    12667
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13130
# Method:                          IRLS   Log-Likelihood:                -5114.6
# Date:                Mon, 25 Feb 2019   Deviance:                       1663.1
# Time:                        09:00:08   Pearson chi2:                 1.66e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4694      0.029     16.106      0.000       0.412       0.527
# validation     0.9718      0.004    226.983      0.000       0.963       0.980
# ==============================================================================
# --- Distribution Test ---
# Ks_2sampResult(statistic=0.18328202699502727, pvalue=8.117407251662937e-186)
# Ttest_relResult(statistic=86.49287115351972, pvalue=0.0)

# %% [markdown]
# # MIMO CNN

# %%
query = {"experiment": "CNN_s2s","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.05)
results.selected_size()

results.plot_map(dset=('test'),figsize=(1200,800))
# Out:
# 6334

# %%
results.sample(1)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test'), figsize=(10,10))
# Out:
# 126692
# MEAN (test)= 6.908812103612164
# StDev (test)= 0.8111056019397442

# %%
results.sample(0.25)
results.selected_size()
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))
# Out:
# 31673

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14293
# Method:                          IRLS   Log-Likelihood:                -14133.
# Date:                Wed, 20 Feb 2019   Deviance:                       4526.7
# Time:                        07:29:58   Pearson chi2:                 4.53e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6992      0.018     37.835      0.000       0.663       0.735
# validation     0.9446      0.003    338.097      0.000       0.939       0.950
# ==============================================================================

# %% [markdown]
# # MIMO RNN

# %%
query = {"experiment": "RNN_s2s","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.05)
results.selected_size()

results.plot_map(dset=('val'),figsize=(1200,800))

# %%
results.sample(1)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test'), figsize=(10,10))
# Out:
# 126692
# MEAN (test)= 6.852182196280556
# StDev (test)= 0.8167559261639322

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:               126692
# Model:                            GLM   Df Residuals:                   126690
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14593
# Method:                          IRLS   Log-Likelihood:                -57851.
# Date:                Mon, 25 Feb 2019   Deviance:                       18488.
# Time:                        10:37:07   Pearson chi2:                 1.85e+04
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6405      0.009     68.895      0.000       0.622       0.659
# validation     0.9507      0.001    672.637      0.000       0.948       0.954
# ==============================================================================

# %% [markdown]
# # MIMO RNN ED

# %%
query = {"experiment": "RNN_ED_s2s_2","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.05)
results.selected_size()

results.plot_map(dset=('val'),figsize=(1200,800))
# Out:
# 6334

# %%
results.sample(1)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test'), figsize=(10,10))
# Out:
# 126692
# MEAN (test)= 6.867959120943678
# StDev (test)= 0.8083999060451638

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14228
# Method:                          IRLS   Log-Likelihood:                -14061.
# Date:                Wed, 20 Feb 2019   Deviance:                       4506.3
# Time:                        07:30:30   Pearson chi2:                 4.51e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7423      0.018     40.340      0.000       0.706       0.778
# validation     0.9355      0.003    335.112      0.000       0.930       0.941
# ==============================================================================

# %% [markdown]
# # MIMO MLP ELU

# %%
query = {"experiment": "MLP_s2s_elu","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
# results.sample(0.15)
# results.selected_size()

# results.plot_map(mapbox=False,dset=('test'),figsize=(1200,800))

# %%
results.sample(1)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP')
# Out:
# 126692
# MEAN (test)= 7.144507067783306
# MEAN (val)= 6.827005804322318

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, test=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                  716
# Model:                            GLM   Df Residuals:                      714
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12389
# Method:                          IRLS   Log-Likelihood:                -267.34
# Date:                Tue, 12 Mar 2019   Deviance:                       88.460
# Time:                        11:30:10   Pearson chi2:                     88.5
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1524      0.108      1.405      0.160      -0.060       0.365
# validation     1.0355      0.016     66.235      0.000       1.005       1.066
# ==============================================================================
# --- Distribution Test ---
# Ks_2sampResult(statistic=0.22206703910614523, pvalue=5.781835878382305e-16)
# Ttest_relResult(statistic=30.06651126348367, pvalue=5.126590324794882e-129)

# %% [markdown]
# # MIMO MLP LeakyElu

# %%
query = {"experiment": "MLP_s2s_leaky","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
# results.sample(0.15)
# results.selected_size()

# results.plot_map(mapbox=False,dset=('test'),figsize=(1200,800))

# %%
results.sample(1)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP')
# Out:
# 126692
# MEAN (test)= 7.141376385319213
# MEAN (val)= 6.824089300048359

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, test=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                  716
# Model:                            GLM   Df Residuals:                      714
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12389
# Method:                          IRLS   Log-Likelihood:                -267.34
# Date:                Tue, 12 Mar 2019   Deviance:                       88.460
# Time:                        11:30:10   Pearson chi2:                     88.5
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1524      0.108      1.405      0.160      -0.060       0.365
# validation     1.0355      0.016     66.235      0.000       1.005       1.066
# ==============================================================================
# --- Distribution Test ---
# Ks_2sampResult(statistic=0.22206703910614523, pvalue=5.781835878382305e-16)
# Ttest_relResult(statistic=30.06651126348367, pvalue=5.126590324794882e-129)

# %% [markdown]
# # MIMO CNN ELU

# %%
query = {"experiment": "CNN_s2s_elu","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126692

# %%
# results.sample(0.15)
# results.selected_size()

# results.plot_map(mapbox=False,dset=('test'),figsize=(1200,800))

# %%
results.sample(1)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP')
# Out:
# 126692
# MEAN (test)= 7.046672585206706
# MEAN (val)= 6.724930384854804

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, test=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                  716
# Model:                            GLM   Df Residuals:                      714
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12389
# Method:                          IRLS   Log-Likelihood:                -267.34
# Date:                Tue, 12 Mar 2019   Deviance:                       88.460
# Time:                        11:30:10   Pearson chi2:                     88.5
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1524      0.108      1.405      0.160      -0.060       0.365
# validation     1.0355      0.016     66.235      0.000       1.005       1.066
# ==============================================================================
# --- Distribution Test ---
# Ks_2sampResult(statistic=0.22206703910614523, pvalue=5.781835878382305e-16)
# Ttest_relResult(statistic=30.06651126348367, pvalue=5.126590324794882e-129)

# %% [markdown]
# # MIMO CNN SMBO

# %%
query = {"experiment": "CNNS2SSMBO", "status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results(query)
results.selected_size()
# Out:
# 126691

# %%
# results.sample(0.15)
# results.selected_size()

# results.plot_map(mapbox=False,dset=('test'),figsize=(1200,800))

# %%
results.sample(1)
results.selected_size()

results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=('test', 'val'), figsize=(10,10),font=16, title='MLP')
# Out:
# 126691
# MEAN (test)= 7.114778328058418
# MEAN (val)= 6.798354892965286

# %%
results.plot_hours_boxplot(dset=('test'),figsize=(8,8))

# %%
results.plot_densplot(plot='regression', glm=True, test=True, figsize=(8,8))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                25898
# Model:                            GLM   Df Residuals:                    25896
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13488
# Method:                          IRLS   Log-Likelihood:                -10805.
# Date:                Mon, 29 Apr 2019   Deviance:                       3492.8
# Time:                        15:59:45   Pearson chi2:                 3.49e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4808      0.020     23.686      0.000       0.441       0.521
# validation     0.9790      0.003    330.231      0.000       0.973       0.985
# ==============================================================================
# --- Distribution Test ---
# Ks_2sampResult(statistic=0.20897366592014832, pvalue=0.0)
# Ttest_relResult(statistic=148.00648026549683, pvalue=0.0)

# %%
query = {"experiment": "MLP_s2s_elu", "status":"done"}
results = DBResults(conn=mongolocaltest)
results.results_dataframe_retrieve(query, arch=[], data=[])
res1 = results.exp_df
res1 = res1.groupby(by=['site'],as_index=False).sum()
print(len(res1))
res1[res1['site']<20000]['test'].mean()
# Out:
# 126692
# 7.424991634513194

# %%
query = {"experiment": "MLPangle", "status":"done"}
results = DBResults(conn=mongolocaltest)
results.results_dataframe_retrieve(query, arch=[], data=[])
res2 = results.exp_df
res2 = res2.groupby(by=['site'],as_index=False).sum()
print(len(res2))
res2[res2['site']<20000]['test'].mean()
# Out:
# 20000
# 7.499502272723784

# %%
query = {"experiment": "CNNS2SSMBO", "status":"done"}
results = DBResults(conn=mongolocaltest)
results.results_dataframe_retrieve(query, arch=[], data=[])
res1 = results.exp_df
res1 = res1.groupby(by=['site'],as_index=False).sum()
print(len(res1[res1['site']<20000]))
res1[res1['site']<20000]['test'].mean()
# Out:
# 20000
# 7.3988724457199

# %%
query = {"experiment": "CNNangle", "status":"done"}
results = DBResults(conn=mongolocaltest)
results.results_dataframe_retrieve(query, arch=[], data=[])
res2 = results.exp_df
res2 = res2.groupby(by=['site'],as_index=False).sum()
print(len(res2[res2['site']<20000]))
res2[res2['site']<20000]['test'].mean()
# Out:
# 20000
# 7.463082606220302
