# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from Wind.Results import DBResults
from Wind.Private.DBConfig import mongoremote,mongolocal,mongolocaltest
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # MIMO MLP vs MIMO RNN

# %%
query1 = {"experiment": "MLP_s2s_2","status":"done"}
query2 = {"experiment": "RNN_s2s","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.9)
results.selected_size()
results.compare_2samp()
# Out:
# 114022
# {'test': {'KS2samp': Ks_2sampResult(statistic=0.13065022539509924, pvalue=0.0),
#   'T-test': Ttest_relResult(statistic=590.7429182977083, pvalue=0.0)},
#  'val': {'KS2samp': Ks_2sampResult(statistic=0.18421883496167407, pvalue=0.0),
#   'T-test': Ttest_relResult(statistic=627.4995453793589, pvalue=0.0)}}

# %%
results.sample(0.05)
results.selected_size()

results.plot_map_compare(dset=('test'),figsize=(1200,800))
# Out:
# 6334

# %%
results.sample(0.25)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary='sum', figsize=(12,12),dset=('test'),title='MLP S2S vs RNN S2S', labels=['test MLP S2S vs RNN S2S'],font=18)
# Out:
# 31673

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary=0, figsize=(10,7),dset=('test'),title='MLP S2S vs RNN S2S', labels=['test MLP S2S vs RNN S2S'],font=18)
# Out:
# 63346

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(14,10), title='MLPS2S vs RNNS2S', labels=['test MLP S2S', 'test RNN S2S'], font=15)

# %%
results.sample(0.25)
results.selected_size()
results.plot_densplot_compare(plot='regression', glm=True, summary='sum', figsize=(8,8))
# Out:
# 31673
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13201
# Method:                          IRLS   Log-Likelihood:                -12874.
# Date:                Wed, 20 Feb 2019   Deviance:                       4180.8
# Time:                        08:10:59   Pearson chi2:                 4.18e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5386      0.018     29.195      0.000       0.502       0.575
# ...

# %% [markdown]
# # MIMO MLP elu vs MIMO RNN ED

# %%
query1 = {"experiment": "MLP_s2s_2,"status":"done"}
query2 = {"experiment": "RNN_ED_s2s_2","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.9)
results.selected_size()
results.compare_2samp()
# Out:
# 114022
# {'test': {'KS2samp': Ks_2sampResult(statistic=0.18472750872638616, pvalue=0.0),
#   'T-test': Ttest_relResult(statistic=681.164830144006, pvalue=0.0)},
#  'val': {'KS2samp': Ks_2sampResult(statistic=0.2160460262054691, pvalue=0.0),
#   'T-test': Ttest_relResult(statistic=661.3243188546576, pvalue=0.0)}}

# %%
results.sample(0.05)
results.selected_size()

results.plot_map_compare(dset=('test'),figsize=(1200,800))
# Out:
# 6334

# %%
results.sample(0.25)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary='sum', figsize=(8,8),dset=('test'))
# Out:
# 31673

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary=0, figsize=(8,8),dset=('test'))
# Out:
# 63346

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(10,6))

# %%
results.sample(0.25)
results.selected_size()
results.plot_densplot_compare(plot='regression', glm=True, summary='sum', figsize=(8,8))
# Out:
# 31673
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13569
# Method:                          IRLS   Log-Likelihood:                -13309.
# Date:                Wed, 20 Feb 2019   Deviance:                       4297.3
# Time:                        08:12:18   Pearson chi2:                 4.30e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5365      0.019     28.522      0.000       0.500       0.573
# ...

# %% [markdown]
# # MIMO MLP vs MIMO CNN elu

# %%
query1 = {"experiment": "MLP_s2s_2","status":"done"}
query2 = {"experiment": "CNN_s2s","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.9)
results.selected_size()
results.compare_2samp()
# Out:
# 114022
# {'test': {'KS2samp': Ks_2sampResult(statistic=0.06405781340443073, pvalue=7.925009332642094e-204),
#   'T-test': Ttest_relResult(statistic=459.18948939025154, pvalue=0.0)},
#  'val': {'KS2samp': Ks_2sampResult(statistic=0.08016873936608726, pvalue=5.2369e-319),
#   'T-test': Ttest_relResult(statistic=416.7443023177508, pvalue=0.0)}}

# %%
results.sample(0.05)
results.selected_size()

results.plot_map_compare(dset=('test'),figsize=(1200,800))
# Out:
# 6334

# %%
results.sample(0.25)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary='sum', figsize=(8,8),dset=('test'))
# Out:
# 31673

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary=0, figsize=(8,8),dset=('test'))
# Out:
# 63346

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(10,6))

# %%
results.sample(0.25)
results.selected_size()
results.plot_densplot_compare(plot='regression', glm=True, summary='sum', figsize=(8,8))
# Out:
# 31673
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13047
# Method:                          IRLS   Log-Likelihood:                -12688.
# Date:                Wed, 20 Feb 2019   Deviance:                       4132.1
# Time:                        08:12:53   Pearson chi2:                 4.13e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4998      0.018     27.216      0.000       0.464       0.536
# ...

# %% [markdown]
# # MIMO RNN ED vs MIMO RNN

# %%
query1 = {"experiment": "RNN_ED_s2s_2","status":"done"}
query2 = {"experiment": "RNN_s2s","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.9)
results.selected_size()
results.compare_2samp()
# Out:
# 114022
# {'test': {'KS2samp': Ks_2sampResult(statistic=0.011681956113732447, pvalue=3.438972527261482e-07),
#   'T-test': Ttest_relResult(statistic=57.38652568723578, pvalue=0.0)},
#  'val': {'KS2samp': Ks_2sampResult(statistic=0.007980915963585966, pvalue=0.0013922748672332338),
#   'T-test': Ttest_relResult(statistic=33.61126985261876, pvalue=1.8599507925015385e-246)}}

# %%
results.sample(0.05)
results.selected_size()

results.plot_map_compare(dset=('test'),figsize=(1200,800))
# Out:
# 6334

# %%
results.sample(0.25)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary='sum', figsize=(8,8),dset=('test'))
# Out:
# 31673

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary=0, figsize=(8,8),dset=('test'))
# Out:
# 63346

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(10,6))

# %%
results.sample(0.25)
results.selected_size()
results.plot_densplot_compare(plot='regression', glm=True, summary='sum', figsize=(8,8))
# Out:
# 31673
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14757
# Method:                          IRLS   Log-Likelihood:                -14639.
# Date:                Wed, 20 Feb 2019   Deviance:                       4673.7
# Time:                        08:13:25   Pearson chi2:                 4.67e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7508      0.019     39.971      0.000       0.714       0.788
# ...

# %% [markdown]
# # MIMO CNN vs MIMO RNN

# %%
query1 = {"experiment": "CNN_s2s","status":"done"}
query2 = {"experiment": "RNN_s2s","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-dbc54af14af2> in <module>
#       2 query2 = {"experiment": "RNN_s2s","status":"done"}
#       3 results = DBResults(conn=mongolocal)
# ----> 4 results.retrieve_results_compare(query1, query2)
#       5 results.selected_size()
#
# ~/PycharmProjects/Wind/Wind/Results/DBResults.py in retrieve_results_compare(self, query1, query2)
#     353             ldata.append((int(exp['data']['datanames'][0].split('-')[1]), data[:, 1], data[:, 2]))
#     354         if len(ldata) == 0:
# --> 355             raise NameError('No results retrieved with first query')
#     356
#     357         ldata = sorted(ldata, key=lambda x: x[0])
#
# NameError: No results retrieved with first query

# %%
results.sample(0.9)
results.selected_size()
results.compare_2samp()

# %%
results.sample(0.8)
results.selected_size()

results.plot_map_compare(mapbox=False,dset=('test'),figsize=(1200,800))
# Out:
# 101353

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary='sum', figsize=(8,8),dset=('val'))

# %%
results.sample(0.25)
results.selected_size()
results.plot_densplot_compare(plot='regression', glm=True, summary='sum', figsize=(8,8))
# Out:
# 31673
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14072
# Method:                          IRLS   Log-Likelihood:                -13886.
# Date:                Wed, 20 Feb 2019   Deviance:                       4456.6
# Time:                        08:14:34   Pearson chi2:                 4.46e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7348      0.018     40.164      0.000       0.699       0.771
# ...

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary=0, figsize=(8,8),dset=('test'))

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(10,6))

# %% [markdown]
# # Multiple Comparison

# %%
query1 = {"experiment": "RNN_s2s","status":"done"}
query2 = {"experiment": "MLP_s2s_2","status":"done"}
#query5 = {"experiment": "MLP_s2s_leaky","status":"done"}
query3 = {"experiment": "CNN_s2s","status":"done"}
query4 = {"experiment": "RNN_ED_s2s_2","status":"done"}
query5 = {"experiment": "CNNS2SSMBO","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results_multiple([query2,query4,query1, query3])
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.4)
results.selected_size()
results.compare_ANOVA(labels=['MLP', 'RNN ED', 'RNN', 'CNN'])
# Out:
# 50676
# One-way ANOVA Test set
# ...
# F value: 667.9673590802898
# P value: 0.0
#
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
# group1 group2 meandiff  lower   upper  reject
# ---------------------------------------------
#  CNN    MLP    0.1483   0.1352  0.1615  True
#  CNN    RNN    -0.056  -0.0692 -0.0429  True
#  CNN   RNN ED -0.0404  -0.0536 -0.0273  True
#  MLP    RNN   -0.2044  -0.2175 -0.1913  True
#  MLP   RNN ED -0.1888  -0.2019 -0.1757  True
#  RNN   RNN ED  0.0156   0.0025  0.0287  True
# ---------------------------------------------
#
# One-way ANOVA Validation set
# ...
# F value: 667.9673590802898
# P value: 0.0
#
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
# group1 group2 meandiff  lower   upper  reject
# ---------------------------------------------
#  CNN    MLP    0.1979   0.1856  0.2101  True
#  CNN    RNN   -0.0397  -0.0519 -0.0274  True
#  CNN   RNN ED -0.0294  -0.0417 -0.0172  True
#  MLP    RNN   -0.2375  -0.2498 -0.2253  True
# ...

# %%
results.sample(0.05)
results.selected_size()
results.plot_map_multiple(summary='sum',notebook=False,dset=('test'), figsize=(1200, 800), labels=['MLP', 'RNN ED', 'RNN', 'CNN'])
# Out:
# 6334
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-a692b725b574> in <module>
#       1 results.sample(0.05)
#       2 results.selected_size()
# ----> 3 results.plot_map_multiple(summary='sum',notebook=False,dset=('test'), figsize=(1200, 800), labels=['MLP', 'RNN ED', 'RNN', 'CNN'])#, cmap=['violet', 'green', 'magenta', 'yellow'])
#
# ~/PycharmProjects/Wind/Wind/Results/DBResults.py in plot_map_multiple(self, summary, notebook, labels, dset, figsize, image, cmap)
#     873         if 'test' in dset:
#     874             create_plot_best(testdf,
# --> 875                         f"{title}-test", notebook=notebook, figsize=figsize, labels=labels,cmap=cmap
#     876                         )
#     877         if 'val' in dset:
#
# ~/PycharmProjects/Wind/Wind/Results/DBResults.py in create_plot_best(df, title, labels, notebook, image, tick, cmap, figsize)
# ...

# %% [markdown]
# # MLP Dir vs MLP MIMO

# %%
from scipy.stats import ks_2samp, ttest_rel,f_oneway
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
query = {"experiment": "MLPDir","status":"done"}
results = DBResults(conn=mongolocal)

results.results_dataframe_retrieve(query,data=[])

# %%
a = results.exp_df.groupby(['site'],as_index=False).sum()
len(a)
# Out:
# 1989

# %%
query = {"experiment": "MLP_s2s_2","status":"done"}
results = DBResults(conn=mongolocaltest)

results.results_dataframe_retrieve(query,data=[])

# %%
b = results.exp_df.groupby(['site'],as_index=False).sum()
c = b.iloc[a['site']]
len(c)
# Out:
# 1989

# %%
plt.figure(figsize=(8,6))
sb.distplot(a['test'],label='MLP dir')
sb.distplot(c['test'],label='MLP s2s')
plt.legend(labels=['MLP dir', 'MLP s2s'], title='Dir vs S2S')

# %%
ks_2samp(a['test'], c['test'])
# Out:
# Ks_2sampResult(statistic=0.17564766839378243, pvalue=1.7181525374654472e-26)

# %%
ttest_rel(a['test'], c['test'])
# Out:
# Ttest_relResult(statistic=-91.327776285756, pvalue=0.0)

# %%
f, p = f_oneway(*[a['test'], c['test']])
f
p
mc = MultiComparison(np.hstack([a['test'], c['test']]), (['MLPDir'] * len(a)) + (['MLPS2S'] * len(a)) )
result = mc.tukeyhsd()
print(result)
# Out:
# 82.35379545366605
# 1.7734962290916744e-19
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
# group1 group2 meandiff lower  upper reject
# ------------------------------------------
# MLPDir MLPS2S  0.2418  0.1896 0.294  True
# ------------------------------------------

# %% [markdown]
# # MLP MIMO vs MLP MIMO elu

# %%
query1 = {"experiment": "MLP_s2s_2","status":"done"}
query2 = {"experiment": "MLP_s2s_elu","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.9)
results.selected_size()
results.compare_2samp()
# Out:
# 114022
# {'test': {'KS2samp': Ks_2sampResult(statistic=0.056550490256266406, pvalue=6.041181253728714e-159),
#   'T-test': Ttest_relResult(statistic=-401.59438252212664, pvalue=0.0)},
#  'val': {'KS2samp': Ks_2sampResult(statistic=0.04384241637578712, pvalue=1.0505276251244504e-95),
#   'T-test': Ttest_relResult(statistic=-237.44775326250385, pvalue=0.0)}}

# %%
results.sample(0.1)
results.selected_size()

results.plot_map_compare(mapbox=False,dset=('test'),figsize=(1200,800))
# Out:
# 12669

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary='sum', figsize=(8,8),dset=('val'))
# Out:
# 63346

# %%
results.sample(0.25)
results.selected_size()
results.plot_densplot_compare(plot='regression', glm=True, summary='sum', figsize=(8,8))
# Out:
# 31673
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13001
# Method:                          IRLS   Log-Likelihood:                -12633.
# Date:                Wed, 20 Mar 2019   Deviance:                       4117.6
# Time:                        09:21:21   Pearson chi2:                 4.12e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5347      0.018     29.128      0.000       0.499       0.571
# ...

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary=0, figsize=(8,8),dset=('test'))
# Out:
# 63346

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(10,6))

# %% [markdown]
# # MLP MIMO leaky vs MLP MIMO

# %%
query1 = {"experiment": "MLP_s2s_2","status":"done"}
query2 = {"experiment": "MLP_s2s_leaky","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.9)
results.selected_size()
results.compare_2samp()
# Out:
# 114022
# {'test': {'KS2samp': Ks_2sampResult(statistic=0.050078055112171393, pvalue=9.796193544647e-125),
#   'T-test': Ttest_relResult(statistic=-526.7649970144635, pvalue=0.0)},
#  'val': {'KS2samp': Ks_2sampResult(statistic=0.03478276122151869, pvalue=2.1395491267871627e-60),
#   'T-test': Ttest_relResult(statistic=-281.50856804586215, pvalue=0.0)}}

# %%
results.sample(0.1)
results.selected_size()

results.plot_map_compare(mapbox=False,dset=('test'),figsize=(1200,800))
# Out:
# 12669

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary='sum', figsize=(8,8),dset=('val'))
# Out:
# 63346

# %%
results.sample(0.25)
results.selected_size()
results.plot_densplot_compare(plot='regression', glm=True, summary='sum', figsize=(8,8))
# Out:
# 31673
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13251
# Method:                          IRLS   Log-Likelihood:                -12933.
# Date:                Fri, 15 Mar 2019   Deviance:                       4196.6
# Time:                        07:13:08   Pearson chi2:                 4.20e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5609      0.019     30.138      0.000       0.524       0.597
# ...

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary=0, figsize=(8,8),dset=('test'))
# Out:
# 63346

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(10,6))

# %% [markdown]
# # CNN MIMO elu vs MLP MIMO

# %%
query1 = {"experiment": "MLP_s2s_2","status":"done"}
query2 = {"experiment": "CNN_s2s_elu","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.9)
results.selected_size()
results.compare_2samp()
# Out:
# 114022
# {'test': {'KS2samp': Ks_2sampResult(statistic=0.022250092087491957, pvalue=5.7679651266400255e-25),
#   'T-test': Ttest_relResult(statistic=166.69165451178847, pvalue=0.0)},
#  'val': {'KS2samp': Ks_2sampResult(statistic=0.02497763589482732, pvalue=2.375439780770692e-31),
#   'T-test': Ttest_relResult(statistic=129.94579254858328, pvalue=0.0)}}

# %%
results.sample(0.1)
results.selected_size()

results.plot_map_compare(mapbox=False,dset=('test'),figsize=(1200,800))
# Out:
# 12669

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary='sum', figsize=(8,8),dset=('val'))
# Out:
# 63346

# %%
results.sample(0.25)
results.selected_size()
results.plot_densplot_compare(plot='regression', glm=True, summary='sum', figsize=(8,8))
# Out:
# 31673
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13632
# Method:                          IRLS   Log-Likelihood:                -13383.
# Date:                Fri, 03 May 2019   Deviance:                       4317.4
# Time:                        10:42:02   Pearson chi2:                 4.32e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6533      0.019     34.811      0.000       0.617       0.690
# ...

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary=0, figsize=(8,8),dset=('test'))
# Out:
# 63346

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(10,6))

# %% [markdown]
# # MLP MIMO elu vs MLP MIMO leaky

# %%
query1 = {"experiment": "MLP_s2s_elu","status":"done"}
query2 = {"experiment": "MLP_s2s_leaky","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.9)
results.selected_size()
results.compare_2samp()
# Out:
# 114022
# {'test': {'KS2samp': Ks_2sampResult(statistic=0.010217326480854605, pvalue=1.3375957916294673e-05),
#   'T-test': Ttest_relResult(statistic=13.654575029408315, pvalue=2.047575902423014e-42)},
#  'val': {'KS2samp': Ks_2sampResult(statistic=0.01607584501236603, pvalue=3.0956237531281094e-13),
#   'T-test': Ttest_relResult(statistic=11.98260727271705, pvalue=4.5885597820177414e-33)}}

# %%
results.sample(0.1)
results.selected_size()

results.plot_map_compare(mapbox=False,dset=('test'),figsize=(1200,800))
# Out:
# 12669

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary='sum', figsize=(8,8),dset=('val'))
# Out:
# 63346

# %%
results.sample(0.25)
results.selected_size()
results.plot_densplot_compare(plot='regression', glm=True, summary='sum', figsize=(8,8))
# Out:
# 31673
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13491
# Method:                          IRLS   Log-Likelihood:                -13219.
# Date:                Wed, 20 Mar 2019   Deviance:                       4272.9
# Time:                        09:20:49   Pearson chi2:                 4.27e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6438      0.019     34.400      0.000       0.607       0.680
# ...

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary=0, figsize=(8,8),dset=('test'))
# Out:
# 63346

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(10,6))

# %% [markdown]
# # MLP MIMO elu vs CNN s2s SMBO

# %%
query1 = {"experiment": "MLP_s2s_elu","status":"done"}
query2 = {"experiment": "CNNS2SSMBO","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 126692

# %%
results.sample(0.9)
results.selected_size()
results.compare_2samp()
# Out:
# 114022
# {'test': {'KS2samp': Ks_2sampResult(statistic=0.02209222781568465, pvalue=1.2823592899553797e-24),
#   'T-test': Ttest_relResult(statistic=166.7333954044483, pvalue=0.0)},
#  'val': {'KS2samp': Ks_2sampResult(statistic=0.02503902755608567, pvalue=1.6731575442413137e-31),
#   'T-test': Ttest_relResult(statistic=129.87140085032337, pvalue=0.0)}}

# %%
results.sample(0.1)
results.selected_size()

results.plot_map_compare(mapbox=False,dset=('test'),figsize=(1200,800))
# Out:
# 12669

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary='sum', figsize=(8,8),dset=('val'))
# Out:
# 63346

# %%
results.sample(0.25)
results.selected_size()
results.plot_densplot_compare(plot='regression', glm=True, summary='sum', figsize=(8,8))
# Out:
# 31673
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                31673
# Model:                            GLM   Df Residuals:                    31671
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13855
# Method:                          IRLS   Log-Likelihood:                -13639.
# Date:                Fri, 03 May 2019   Deviance:                       4387.9
# Time:                        10:43:27   Pearson chi2:                 4.39e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6621      0.019     34.921      0.000       0.625       0.699
# ...

# %%
results.sample(0.5)
results.selected_size()
results.plot_distplot_compare(seaborn=True, summary=0, figsize=(8,8),dset=('test'))
# Out:
# 63346

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(10,6))
