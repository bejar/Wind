# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Wind.Results import DBResults
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import seaborn as sns
from Wind.Private.DBConfig import mongolocaltest, mongolocal
import matplotlib.pyplot as plt
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # Fitting RNN Encoder Decoder separated dependent variables

# %% [markdown]
# ## Fit 1

# %% [markdown]
# fit of RNN, explore lag, decoder/encoder neurons, dropout and encoder layers

# %%
query={'experiment':'rnneds2sdepfit'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()

results.retrieve_results_dataframe(query, arch=['neuronsD', 'neuronsE','nlayersE','nlayersD', 'drop'], data=['lag'])

# %%
a=results.exp_df.groupby(['site', 'drop', 'neuronsD', 'lag','nlayersE','nlayersD', 'neuronsE'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)
len(a)
# Out:
# 6400

# %%
a.boxplot(by=['neuronsD', 'neuronsE',  'nlayersE','nlayersD', 'drop', 'lag' ],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f88e055f9b0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f88e21de160>],
#       dtype=object)

# %%
b =a.groupby(by=['neuronsD', 'neuronsE',  'nlayersE','nlayersD', 'drop', 'lag' ],as_index=False).mean()
b.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow24_col6 {
#             background-color:  yellow;
#         }    #T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow24_col7 {
#             background-color:  yellow;
#         }</style><table id="T_4446d5c0_30e1_11e9_8760_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >neuronsD</th>        <th class="col_heading level0 col1" >neuronsE</th>        <th class="col_heading level0 col2" >nlayersE</th>        <th class="col_heading level0 col3" >nlayersD</th>        <th class="col_heading level0 col4" >drop</th>        <th class="col_heading level0 col5" >lag</th>        <th class="col_heading level0 col6" >test</th>        <th class="col_heading level0 col7" >val</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow0_col0" class="data row0 col0" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow0_col1" class="data row0 col1" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow0_col3" class="data row0 col3" >1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow0_col4" class="data row0 col4" >0.0</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow0_col5" class="data row0 col5" >12</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow0_col6" class="data row0 col6" >6.86731</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow0_col7" class="data row0 col7" >6.54547</td>
#             </tr>
#             <tr>
#                         <th id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow1_col0" class="data row1 col0" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow1_col1" class="data row1 col1" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow1_col2" class="data row1 col2" >1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow1_col4" class="data row1 col4" >0.0</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow1_col5" class="data row1 col5" >18</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow1_col6" class="data row1 col6" >6.86402</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow1_col7" class="data row1 col7" >6.52998</td>
#             </tr>
#             <tr>
#                         <th id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow2_col0" class="data row2 col0" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow2_col1" class="data row2 col1" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow2_col3" class="data row2 col3" >1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow2_col4" class="data row2 col4" >0.1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow2_col5" class="data row2 col5" >12</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow2_col6" class="data row2 col6" >6.84258</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow2_col7" class="data row2 col7" >6.51958</td>
#             </tr>
#             <tr>
#                         <th id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow3_col0" class="data row3 col0" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow3_col1" class="data row3 col1" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow3_col2" class="data row3 col2" >1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow3_col3" class="data row3 col3" >1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow3_col4" class="data row3 col4" >0.1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow3_col5" class="data row3 col5" >18</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow3_col6" class="data row3 col6" >6.83488</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow3_col7" class="data row3 col7" >6.50503</td>
#             </tr>
#             <tr>
#                         <th id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow4_col0" class="data row4 col0" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow4_col1" class="data row4 col1" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow4_col2" class="data row4 col2" >2</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow4_col3" class="data row4 col3" >1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow4_col4" class="data row4 col4" >0.0</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow4_col5" class="data row4 col5" >12</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow4_col6" class="data row4 col6" >6.83336</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow4_col7" class="data row4 col7" >6.51264</td>
#             </tr>
#             <tr>
#                         <th id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow5_col0" class="data row5 col0" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow5_col1" class="data row5 col1" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow5_col2" class="data row5 col2" >2</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow5_col3" class="data row5 col3" >1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow5_col4" class="data row5 col4" >0.0</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow5_col5" class="data row5 col5" >18</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow5_col6" class="data row5 col6" >6.83124</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow5_col7" class="data row5 col7" >6.49946</td>
#             </tr>
#             <tr>
#                         <th id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow6_col0" class="data row6 col0" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow6_col1" class="data row6 col1" >128</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow6_col2" class="data row6 col2" >2</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow6_col3" class="data row6 col3" >1</td>
#                         <td id="T_4446d5c0_30e1_11e9_8760_842b2bb021fdrow6_col4" class="data row6 col4" >0.1</td>
#                         <td id="T

# %%
sns.kdeplot(b['test'],b['val'])

# %% [markdown]
# final best configuration

# %%
a.groupby(by=['neuronsD', 'neuronsE',  'nlayersE', 'drop', 'lag' ],as_index=False).count()
# Out:
#    neuronsD neuronsE nlayersE drop lag  nlayersD  test  val
# 0       128      128        1  0.0  12       200   200  200
# 1       128      128        1  0.0  18       200   200  200
# 2       128      128        1  0.1  12       200   200  200
# 3       128      128        1  0.1  18       200   200  200
# 4       128      128        2  0.0  12       200   200  200
# 5       128      128        2  0.0  18       200   200  200
# 6       128      128        2  0.1  12       200   200  200
# 7       128      128        2  0.1  18       200   200  200
# 8       128      196        1  0.0  12       200   200  200
# 9       128      196        1  0.0  18       200   200  200
# 10      128      196        1  0.1  12       200   200  200
# 11      128      196        1  0.1  18       200   200  200
# 12      128      196        2  0.0  12       200   200  200
# 13      128      196        2  0.0  18       200   200  200
# 14      128      196        2  0.1  12       200   200  200
# 15      128      196        2  0.1  18       200   200  200
# 16      196      128        1  0.0  12       200   200  200
# 17      196      128        1  0.0  18       200   200  200
# 18      196      128        1  0.1  12       200   200  200
# 19      196      128        1  0.1  18       200   200  200
# 20      196      128        2  0.0  12       200   200  200
# 21      196      128        2  0.0  18       200   200  200
# 22      196      128        2  0.1  12       200   200  200
# 23      196      128        2  0.1  18       200   200  200
# 24      196      196        1  0.0  12       200   200  200
# 25      196      196        1  0.0  18       200   200  200
# 26      196      196        1  0.1  12       200   200  200
# 27      196      196        1  0.1  18       200   200  200
# 28      196      196        2  0.0  12       200   200  200
# 29      196      196        2  0.0  18       200   200  200
# 30      196      196        2  0.1  12       200   200  200
# 31      196      196        2  0.1  18       200   200  200

# %% [markdown]
# ## Fit 2

# %%
query={'experiment':'rnneds2sdepfit2'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()

results.retrieve_results_dataframe(query, arch=['neuronsD', 'neuronsE','nlayersE','nlayersD', 'drop'], data=['lag'])

# %%
a=results.exp_df.groupby(['site', 'drop', 'neuronsD', 'lag','nlayersE','nlayersD', 'neuronsE'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)
len(a)
# Out:
# 19200

# %%
a.boxplot(by=['neuronsD', 'neuronsE',  'nlayersE','nlayersD', 'drop', 'lag' ],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f88cc9feba8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f88e16aaf60>],
#       dtype=object)

# %%
b =a.groupby(by=['neuronsD', 'neuronsE',  'nlayersE','nlayersD', 'drop', 'lag' ],as_index=False).mean()
b[b['test']>6.86].style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow6_col6 {
#             background-color:  yellow;
#         }    #T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow7_col7 {
#             background-color:  yellow;
#         }</style><table id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >neuronsD</th>        <th class="col_heading level0 col1" >neuronsE</th>        <th class="col_heading level0 col2" >nlayersE</th>        <th class="col_heading level0 col3" >nlayersD</th>        <th class="col_heading level0 col4" >drop</th>        <th class="col_heading level0 col5" >lag</th>        <th class="col_heading level0 col6" >test</th>        <th class="col_heading level0 col7" >val</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow0_col0" class="data row0 col0" >128</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow0_col1" class="data row0 col1" >196</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow0_col3" class="data row0 col3" >1</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow0_col4" class="data row0 col4" >0.0</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow0_col5" class="data row0 col5" >12</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow0_col6" class="data row0 col6" >6.87536</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow0_col7" class="data row0 col7" >6.54526</td>
#             </tr>
#             <tr>
#                         <th id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow1_col0" class="data row1 col0" >128</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow1_col1" class="data row1 col1" >196</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow1_col2" class="data row1 col2" >1</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow1_col4" class="data row1 col4" >0.0</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow1_col5" class="data row1 col5" >15</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow1_col6" class="data row1 col6" >6.8738</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow1_col7" class="data row1 col7" >6.54675</td>
#             </tr>
#             <tr>
#                         <th id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdlevel0_row2" class="row_heading level0 row2" >6</th>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow2_col0" class="data row2 col0" >128</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow2_col1" class="data row2 col1" >196</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow2_col3" class="data row2 col3" >2</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow2_col4" class="data row2 col4" >0.0</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow2_col5" class="data row2 col5" >12</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow2_col6" class="data row2 col6" >6.87372</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow2_col7" class="data row2 col7" >6.5461</td>
#             </tr>
#             <tr>
#                         <th id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdlevel0_row3" class="row_heading level0 row3" >7</th>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow3_col0" class="data row3 col0" >128</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow3_col1" class="data row3 col1" >196</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow3_col2" class="data row3 col2" >1</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow3_col3" class="data row3 col3" >2</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow3_col4" class="data row3 col4" >0.0</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow3_col5" class="data row3 col5" >15</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow3_col6" class="data row3 col6" >6.87394</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow3_col7" class="data row3 col7" >6.54514</td>
#             </tr>
#             <tr>
#                         <th id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdlevel0_row4" class="row_heading level0 row4" >24</th>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow4_col0" class="data row4 col0" >128</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow4_col1" class="data row4 col1" >256</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow4_col2" class="data row4 col2" >1</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow4_col3" class="data row4 col3" >1</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow4_col4" class="data row4 col4" >0.0</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow4_col5" class="data row4 col5" >12</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow4_col6" class="data row4 col6" >6.86978</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow4_col7" class="data row4 col7" >6.54976</td>
#             </tr>
#             <tr>
#                         <th id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdlevel0_row5" class="row_heading level0 row5" >25</th>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow5_col0" class="data row5 col0" >128</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow5_col1" class="data row5 col1" >256</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow5_col2" class="data row5 col2" >1</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow5_col3" class="data row5 col3" >1</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow5_col4" class="data row5 col4" >0.0</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow5_col5" class="data row5 col5" >15</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow5_col6" class="data row5 col6" >6.86984</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow5_col7" class="data row5 col7" >6.54616</td>
#             </tr>
#             <tr>
#                         <th id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdlevel0_row6" class="row_heading level0 row6" >30</th>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow6_col0" class="data row6 col0" >128</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow6_col1" class="data row6 col1" >256</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow6_col2" class="data row6 col2" >1</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow6_col3" class="data row6 col3" >2</td>
#                         <td id="T_1a2c8f44_30e3_11e9_8760_842b2bb021fdrow6_col4" class="data row6 col4" >0.0</td>
#                         <td id="T_

# %%
sns.kdeplot(b['test'],b['val'])
#sns.kdeplot(a['test'],a['val'])

# %%
a.groupby(by=['neuronsD', 'neuronsE',  'nlayersE','nlayersD', 'drop', 'lag'  ],as_index=False).count()
# Out:
#    neuronsD neuronsE nlayersE nlayersD drop lag  test  val
# 0       128      196        1        1  0.0  12   200  200
# 1       128      196        1        1  0.0  15   200  200
# 2       128      196        1        1  0.1  12   200  200
# 3       128      196        1        1  0.1  15   200  200
# 4       128      196        1        1  0.2  12   200  200
# 5       128      196        1        1  0.2  15   200  200
# 6       128      196        1        2  0.0  12   200  200
# 7       128      196        1        2  0.0  15   200  200
# 8       128      196        1        2  0.1  12   200  200
# 9       128      196        1        2  0.1  15   200  200
# 10      128      196        1        2  0.2  12   200  200
# 11      128      196        1        2  0.2  15   200  200
# 12      128      196        2        1  0.0  12   200  200
# 13      128      196        2        1  0.0  15   200  200
# 14      128      196        2        1  0.1  12   200  200
# 15      128      196        2        1  0.1  15   200  200
# 16      128      196        2        1  0.2  12   200  200
# 17      128      196        2        1  0.2  15   200  200
# 18      128      196        2        2  0.0  12   200  200
# 19      128      196        2        2  0.0  15   200  200
# 20      128      196        2        2  0.1  12   200  200
# 21      128      196        2        2  0.1  15   200  200
# 22      128      196        2        2  0.2  12   200  200
# 23      128      196        2        2  0.2  15   200  200
# 24      128      256        1        1  0.0  12   200  200
# 25      128      256        1        1  0.0  15   200  200
# 26      128      256        1        1  0.1  12   200  200
# 27      128      256        1        1  0.1  15   200  200
# 28      128      256        1        1  0.2  12   200  200
# 29      128      256        1        1  0.2  15   200  200
# ..      ...      ...      ...      ...  ...  ..   ...  ...
# 66       64      196        2        2  0.0  12   200  200
# 67       64      196        2        2  0.0  15   200  200
# 68       64      196        2        2  0.1  12   200  200
# 69       64      196        2        2  0.1  15   200  200
# 70       64      196        2        2  0.2  12   200  200
# 71       64      196        2        2  0.2  15   200  200
# 72       64      256        1        1  0.0  12   200  200
# 73       64      256        1        1  0.0  15   200  200
# 74       64      256        1        1  0.1  12   200  200
# 75       64      256        1        1  0.1  15   200  200
# 76       64      256        1        1  0.2  12   200  200
# 77       64      256        1        1  0.2  15   200  200
# 78       64      256        1        2  0.0  12   200  200
# 79       64      256        1        2  0.0  15   200  200
# 80       64      256        1        2  0.1  12   200  200
# 81       64      256        1        2  0.1  15   200  200
# 82       64      256        1        2  0.2  12   200  200
# 83       64      256        1        2  0.2  15   200  200
# 84       64      256        2        1  0.0  12   200  200
# 85       64      256        2        1  0.0  15   200  200
# 86       64      256        2        1  0.1  12   200  200
# 87       64      256        2        1  0.1  15   200  200
# 88       64      256        2        1  0.2  12   200  200
# 89       64      256        2        1  0.2  15   200  200
# 90       64      256        2        2  0.0  12   200  200
# 91       64      256        2        2  0.0  15   200  200
# 92       64      256        2        2  0.1  12   200  200
# 93       64      256        2        2  0.1  15   200  200
# 94       64      256        2        2  0.2  12   200  200
# 95       64      256        2        2  0.2  15   200  200
#
# [96 rows x 8 columns]

# %% [markdown]
# ## Fit 3

# %%
query={'experiment':'rnneds2sdepfit3'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()

results.retrieve_results_dataframe(query, arch=['neuronsD', 'neuronsE','nlayersE','nlayersD', 'drop','activation'], data=['lag'])

# %%
a=results.exp_df.groupby(['site', 'drop', 'neuronsD', 'lag','nlayersE','nlayersD', 'neuronsE','activation'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)
len(a)
# Out:
# 70070

# %%
a.boxplot(by=['neuronsD', 'neuronsE',  'nlayersE','nlayersD', 'drop', 'lag','activation' ],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0e3f11f438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e36c486a0>],
#       dtype=object)

# %%
b =a.groupby(by=['neuronsD', 'neuronsE',  'nlayersE','nlayersD', 'drop', 'lag','activation' ],as_index=False).mean()
b[b['test']>6.9].style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow12_col7 {
#             background-color:  yellow;
#         }    #T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow12_col8 {
#             background-color:  yellow;
#         }</style><table id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >neuronsD</th>        <th class="col_heading level0 col1" >neuronsE</th>        <th class="col_heading level0 col2" >nlayersE</th>        <th class="col_heading level0 col3" >nlayersD</th>        <th class="col_heading level0 col4" >drop</th>        <th class="col_heading level0 col5" >lag</th>        <th class="col_heading level0 col6" >activation</th>        <th class="col_heading level0 col7" >test</th>        <th class="col_heading level0 col8" >val</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdlevel0_row0" class="row_heading level0 row0" >23</th>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow0_col0" class="data row0 col0" >196</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow0_col1" class="data row0 col1" >256</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow0_col3" class="data row0 col3" >2</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow0_col4" class="data row0 col4" >0.0</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow0_col5" class="data row0 col5" >15</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow0_col6" class="data row0 col6" >sigmoid</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow0_col7" class="data row0 col7" >6.90501</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow0_col8" class="data row0 col8" >6.56107</td>
#             </tr>
#             <tr>
#                         <th id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdlevel0_row1" class="row_heading level0 row1" >160</th>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow1_col0" class="data row1 col0" >196</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow1_col1" class="data row1 col1" >512</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow1_col2" class="data row1 col2" >1</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow1_col3" class="data row1 col3" >3</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow1_col4" class="data row1 col4" >0.0</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow1_col5" class="data row1 col5" >12</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow1_col6" class="data row1 col6" >relu</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow1_col7" class="data row1 col7" >6.90407</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow1_col8" class="data row1 col8" >6.57246</td>
#             </tr>
#             <tr>
#                         <th id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdlevel0_row2" class="row_heading level0 row2" >201</th>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow2_col0" class="data row2 col0" >196</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow2_col1" class="data row2 col1" >512</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow2_col2" class="data row2 col2" >2</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow2_col3" class="data row2 col3" >2</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow2_col4" class="data row2 col4" >0.0</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow2_col5" class="data row2 col5" >12</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow2_col6" class="data row2 col6" >sigmoid</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow2_col7" class="data row2 col7" >6.90688</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow2_col8" class="data row2 col8" >6.54664</td>
#             </tr>
#             <tr>
#                         <th id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdlevel0_row3" class="row_heading level0 row3" >221</th>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow3_col0" class="data row3 col0" >196</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow3_col1" class="data row3 col1" >512</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow3_col2" class="data row3 col2" >2</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow3_col3" class="data row3 col3" >3</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow3_col4" class="data row3 col4" >0.0</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow3_col5" class="data row3 col5" >12</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow3_col6" class="data row3 col6" >sigmoid</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow3_col7" class="data row3 col7" >6.90938</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow3_col8" class="data row3 col8" >6.57429</td>
#             </tr>
#             <tr>
#                         <th id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdlevel0_row4" class="row_heading level0 row4" >258</th>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow4_col0" class="data row4 col0" >256</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow4_col1" class="data row4 col1" >256</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow4_col2" class="data row4 col2" >1</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow4_col3" class="data row4 col3" >1</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow4_col4" class="data row4 col4" >0.05</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow4_col5" class="data row4 col5" >24</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow4_col6" class="data row4 col6" >relu</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow4_col7" class="data row4 col7" >6.90017</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow4_col8" class="data row4 col8" >6.55559</td>
#             </tr>
#             <tr>
#                         <th id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdlevel0_row5" class="row_heading level0 row5" >261</th>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow5_col0" class="data row5 col0" >256</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow5_col1" class="data row5 col1" >256</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow5_col2" class="data row5 col2" >1</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow5_col3" class="data row5 col3" >2</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow5_col4" class="data row5 col4" >0.0</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow5_col5" class="data row5 col5" >12</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow5_col6" class="data row5 col6" >sigmoid</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow5_col7" class="data row5 col7" >6.96098</td>
#                         <td id="T_ca39a112_38c0_11e9_a5ef_842b2bb021fdrow5_col8" class="data row5 col

# %%
sns.kdeplot(b['test'],b['val'])
#sns.kdeplot(a['test'],a['val'])

# %%
a.groupby(by=['neuronsD', 'neuronsE',  'nlayersE','nlayersD', 'drop', 'lag','activation'  ],as_index=False).count()
# Out:
#     neuronsD neuronsE nlayersE nlayersD  drop lag activation  test  val
# 0        196      256        1        1   0.0  12       relu   193  193
# 1        196      256        1        1   0.0  12    sigmoid   147  147
# 2        196      256        1        1   0.0  15       relu   197  197
# 3        196      256        1        1   0.0  15    sigmoid   148  148
# 4        196      256        1        1   0.0  18       relu   189  189
# 5        196      256        1        1   0.0  18    sigmoid   152  152
# 6        196      256        1        1   0.0  21       relu   191  191
# 7        196      256        1        1   0.0  21    sigmoid   146  146
# 8        196      256        1        1   0.0  24       relu   188  188
# 9        196      256        1        1   0.0  24    sigmoid   143  143
# 10       196      256        1        1  0.05  12       relu   192  192
# 11       196      256        1        1  0.05  12    sigmoid   156  156
# 12       196      256        1        1  0.05  15       relu   193  193
# 13       196      256        1        1  0.05  15    sigmoid   150  150
# 14       196      256        1        1  0.05  18       relu   190  190
# 15       196      256        1        1  0.05  18    sigmoid   148  148
# 16       196      256        1        1  0.05  21       relu   188  188
# 17       196      256        1        1  0.05  21    sigmoid   152  152
# 18       196      256        1        1  0.05  24       relu   189  189
# 19       196      256        1        1  0.05  24    sigmoid   160  160
# 20       196      256        1        2   0.0  12       relu   188  188
# 21       196      256        1        2   0.0  12    sigmoid   112  112
# 22       196      256        1        2   0.0  15       relu   188  188
# 23       196      256        1        2   0.0  15    sigmoid   119  119
# 24       196      256        1        2   0.0  18       relu   191  191
# 25       196      256        1        2   0.0  18    sigmoid   128  128
# 26       196      256        1        2   0.0  21       relu   193  193
# 27       196      256        1        2   0.0  21    sigmoid   117  117
# 28       196      256        1        2   0.0  24       relu   189  189
# 29       196      256        1        2   0.0  24    sigmoid   109  109
# ..       ...      ...      ...      ...   ...  ..        ...   ...  ...
# 450      256      512        2        2  0.05  12       relu   172  172
# 451      256      512        2        2  0.05  12    sigmoid   101  101
# 452      256      512        2        2  0.05  15       relu   167  167
# 453      256      512        2        2  0.05  15    sigmoid    95   95
# 454      256      512        2        2  0.05  18       relu   165  165
# 455      256      512        2        2  0.05  18    sigmoid   104  104
# 456      256      512        2        2  0.05  21       relu   177  177
# 457      256      512        2        2  0.05  21    sigmoid    97   97
# 458      256      512        2        2  0.05  24       relu   166  166
# 459      256      512        2        2  0.05  24    sigmoid    92   92
# 460      256      512        2        3   0.0  12       relu   166  166
# 461      256      512        2        3   0.0  12    sigmoid    73   73
# 462      256      512        2        3   0.0  15       relu   157  157
# 463      256      512        2        3   0.0  15    sigmoid    78   78
# 464      256      512        2        3   0.0  18       relu   169  169
# 465      256      512        2        3   0.0  18    sigmoid    85   85
# 466      256      512        2        3   0.0  21       relu   159  159
# 467      256      512        2        3   0.0  21    sigmoid    87   87
# 468      256      512        2        3   0.0  24       relu   158  158
# 469      256      512        2        3   0.0  24    sigmoid    79   79
# 470      256      512        2        3  0.05  12       relu   149  149
# 471      256      512        2        3  0.05  12    sigmoid    82   82
# 472      256      512        2        3  0.05  15       relu   149  149
# 473      256      512        2        3  0.05  15    sigmoid    77   77
# 474      256      512        2        3  0.05  18       relu   143  143
# 475      256      512        2        3  0.05  18    sigmoid    81   81
# 476      256      512        2        3  0.05  21       relu   156  156
# 477      256      512        2        3  0.05  21    sigmoid    84   84
# 478      256      512        2        3  0.05  24       relu   148  148
# 479      256      512        2        3  0.05  24    sigmoid    90   90
#
# [480 rows x 9 columns]

# %% [markdown]
# # Fitting RNN Encoder Decoder with attention

# %% [markdown]
# ## Fit1

# %%
query={'experiment':'rnneds2satt'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()

results.retrieve_results_dataframe(query, arch=['neurons', 'nlayersD','nlayersE', 'drop'], data=['lag'])

# %%
a=results.exp_df.groupby(['site', 'drop', 'neurons', 'lag','nlayersE', 'nlayersD'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)
len(a)
# Out:
# 200

# %%
a.boxplot(by=[ 'drop', 'neurons', 'lag','nlayersE', 'nlayersD'],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f9cf286d550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f9cf5619668>],
#       dtype=object)

# %%
b =a.groupby(by=[ 'drop', 'neurons', 'lag','nlayersE', 'nlayersD'],as_index=False).mean()
b.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_a2a61d7a_2ea6_11e9_a7e7_842b2bb021fdrow0_col5 {
#             background-color:  yellow;
#         }    #T_a2a61d7a_2ea6_11e9_a7e7_842b2bb021fdrow0_col6 {
#             background-color:  yellow;
#         }</style><table id="T_a2a61d7a_2ea6_11e9_a7e7_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >drop</th>        <th class="col_heading level0 col1" >neurons</th>        <th class="col_heading level0 col2" >lag</th>        <th class="col_heading level0 col3" >nlayersE</th>        <th class="col_heading level0 col4" >nlayersD</th>        <th class="col_heading level0 col5" >test</th>        <th class="col_heading level0 col6" >val</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a2a61d7a_2ea6_11e9_a7e7_842b2bb021fdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a2a61d7a_2ea6_11e9_a7e7_842b2bb021fdrow0_col0" class="data row0 col0" >0.0</td>
#                         <td id="T_a2a61d7a_2ea6_11e9_a7e7_842b2bb021fdrow0_col1" class="data row0 col1" >196</td>
#                         <td id="T_a2a61d7a_2ea6_11e9_a7e7_842b2bb021fdrow0_col2" class="data row0 col2" >18</td>
#                         <td id="T_a2a61d7a_2ea6_11e9_a7e7_842b2bb021fdrow0_col3" class="data row0 col3" >1</td>
#                         <td id="T_a2a61d7a_2ea6_11e9_a7e7_842b2bb021fdrow0_col4" class="data row0 col4" >1</td>
#                         <td id="T_a2a61d7a_2ea6_11e9_a7e7_842b2bb021fdrow0_col5" class="data row0 col5" >5.80838</td>
#                         <td id="T_a2a61d7a_2ea6_11e9_a7e7_842b2bb021fdrow0_col6" class="data row0 col6" >5.34584</td>
#             </tr>
#     </tbody></table>

# %%
a.groupby(by=[ 'drop', 'neurons', 'lag','nlayersE', 'nlayersD'],as_index=False).count()
# Out:
#   drop neurons lag nlayersE nlayersD  test  val
# 0  0.0     196  18        1        1   200  200
