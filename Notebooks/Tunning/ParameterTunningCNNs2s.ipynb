# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Wind.Results import DBResults
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import seaborn as sns
from Wind.Private.DBConfig import mongolocaltest, mongolocal
import matplotlib.pyplot as plt
import plotly.offline as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # Fitting CNN s2s

# %% [markdown]
# ## Fit1

# %%
query={'experiment':'cnns2sfit'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()

results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop'], data=['lag'])

# %%
a=results.exp_df.groupby(['site','filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)

# %%
a[(a['lag']=='12') & (a['filters']=='[64]') &  (a['kernel_size']=='[5]')].boxplot(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fbf5408e8d0>,
# ...
#       dtype=object)

# %%
b =a.groupby(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).mean()
b[(b['lag']=='18') & (b['filters']=='[64]')].style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_450c3a00_4558_11e9_800f_842b2bb021fdrow30_col7 {
#             background-color:  yellow;
#         }    #T_450c3a00_4558_11e9_800f_842b2bb021fdrow31_col8 {
#             background-color:  yellow;
#         }</style><table id="T_450c3a00_4558_11e9_800f_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >filters</th>        <th class="col_heading level0 col1" >strides</th>        <th class="col_heading level0 col2" >kernel_size</th>        <th class="col_heading level0 col3" >drop</th>        <th class="col_heading level0 col4" >full</th>        <th class="col_heading level0 col5" >fulldrop</th>        <th class="col_heading level0 col6" >lag</th>        <th class="col_heading level0 col7" >test</th>        <th class="col_heading level0 col8" >val</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
trace = []
for v in ['6', '12', '18', '24']:
    trace.append(go.Scatter(
        x = b[b['lag']==v]['test'],
        y = b[b['lag']==v]['val'],
        text='F-'+b[b['lag']==v]['full'].astype(str) + 'D-' + b[b['lag']==v]['drop'].astype(str) + '-L' + b[b['lag']==v]['lag'].astype(str)+ '-A' + b[b['lag']==v]['filters'].astype(str), 
        mode = 'markers', name=v
    ))
py.iplot(trace, filename='basic-scatter')
# Out:
# <div id="994695df-49b3-48b7-afaa-e4251b0bad38" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("994695df-49b3-48b7-afaa-e4251b0bad38")) {
# ...

# %% [markdown]
# Best model CNN(64/1/5,0.1) FC(64,0) L(18)

# %% [markdown]
# ## Fit 2

# %%
query={'experiment':'cnns2sfit2'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()
results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop'], data=['lag'])

# %%
a=results.exp_df.groupby(['site','filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)

# %%
a.boxplot(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fbf577f3be0>,
# ...
#       dtype=object)

# %%
b =a.groupby(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).mean()
b.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_4a97c7a0_4558_11e9_800f_842b2bb021fdrow6_col7 {
#             background-color:  yellow;
#         }    #T_4a97c7a0_4558_11e9_800f_842b2bb021fdrow6_col8 {
#             background-color:  yellow;
#         }</style><table id="T_4a97c7a0_4558_11e9_800f_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >filters</th>        <th class="col_heading level0 col1" >strides</th>        <th class="col_heading level0 col2" >kernel_size</th>        <th class="col_heading level0 col3" >drop</th>        <th class="col_heading level0 col4" >full</th>        <th class="col_heading level0 col5" >fulldrop</th>        <th class="col_heading level0 col6" >lag</th>        <th class="col_heading level0 col7" >test</th>        <th class="col_heading level0 col8" >val</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
trace = []
for v in ['6', '12', '18', '24']:
    trace.append(go.Scatter(
        x = b[b['lag']==v]['test'],
        y = b[b['lag']==v]['val'],
        text='F-'+b[b['lag']==v]['full'].astype(str) + 'D-' + b[b['lag']==v]['drop'].astype(str) + '-L' + b[b['lag']==v]['lag'].astype(str)+ '-A' + b[b['lag']==v]['filters'].astype(str), 
        mode = 'markers', name=v
    ))
py.iplot(trace, filename='basic-scatter')
# Out:
# <div id="e06111e0-abb5-45d3-aac8-2e306b0b9660" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("e06111e0-abb5-45d3-aac8-2e306b0b9660")) {
# ...

# %% [markdown]
# Best model CNN(128/1/5,0.2) FC(32,0) L(18)

# %% [markdown]
# ## Fit 3

# %%
query={'experiment':'cnns2sfit3'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()
results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop'], data=['lag'])

# %%
a=results.exp_df.groupby(['site','filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)

# %%
a.boxplot(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fbf379e6b70>,
# ...
#       dtype=object)

# %%
b =a.groupby(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).mean()
b.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_4de28c9c_4558_11e9_800f_842b2bb021fdrow0_col8 {
#             background-color:  yellow;
#         }    #T_4de28c9c_4558_11e9_800f_842b2bb021fdrow12_col7 {
#             background-color:  yellow;
#         }</style><table id="T_4de28c9c_4558_11e9_800f_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >filters</th>        <th class="col_heading level0 col1" >strides</th>        <th class="col_heading level0 col2" >kernel_size</th>        <th class="col_heading level0 col3" >drop</th>        <th class="col_heading level0 col4" >full</th>        <th class="col_heading level0 col5" >fulldrop</th>        <th class="col_heading level0 col6" >lag</th>        <th class="col_heading level0 col7" >test</th>        <th class="col_heading level0 col8" >val</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
trace = []
for v in ['6', '12', '18', '24']:
    trace.append(go.Scatter(
        x = b[b['lag']==v]['test'],
        y = b[b['lag']==v]['val'],
        text='F-'+b[b['lag']==v]['full'].astype(str) + 'D-' + b[b['lag']==v]['drop'].astype(str) + '-L' + b[b['lag']==v]['lag'].astype(str)+ '-A' + b[b['lag']==v]['filters'].astype(str), 
        mode = 'markers', name=v
    ))
py.iplot(trace, filename='basic-scatter')
# Out:
# <div id="d1e0746a-4ec0-42b6-a582-78c8b2f00f3c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("d1e0746a-4ec0-42b6-a582-78c8b2f00f3c")) {
# ...

# %% [markdown]
# Best Model CNN(256/1/5,0.2) FC(32, 0) L(18)

# %% [markdown]
# ## Fit 4

# %%
query={'experiment':'cnns2sfit4'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()
results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop'], data=['lag'])

# %%
a=results.exp_df.groupby(['site','filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)

# %%
a.boxplot(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe662d86a58>,
# ...
#       dtype=object)

# %%
b =a.groupby(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).mean()
b.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_2836e202_419a_11e9_9e60_842b2bb021fdrow1_col7 {
#             background-color:  yellow;
#         }    #T_2836e202_419a_11e9_9e60_842b2bb021fdrow1_col8 {
#             background-color:  yellow;
#         }</style><table id="T_2836e202_419a_11e9_9e60_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >filters</th>        <th class="col_heading level0 col1" >strides</th>        <th class="col_heading level0 col2" >kernel_size</th>        <th class="col_heading level0 col3" >drop</th>        <th class="col_heading level0 col4" >full</th>        <th class="col_heading level0 col5" >fulldrop</th>        <th class="col_heading level0 col6" >lag</th>        <th class="col_heading level0 col7" >test</th>        <th class="col_heading level0 col8" >val</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
#sns.kdeplot(b['test'],b['val'])

# %% [markdown]
# ## Fit 5

# %%
query={'experiment':'cnns2sfit5'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()
results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop'], data=['lag'])

# %%
a=results.exp_df.groupby(['site','filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)

# %%
a.boxplot(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe660dcdeb8>,
# ...
#       dtype=object)

# %%
b =a.groupby(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).mean()
b.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_30ef48f8_419a_11e9_9e60_842b2bb021fdrow12_col7 {
#             background-color:  yellow;
#         }    #T_30ef48f8_419a_11e9_9e60_842b2bb021fdrow13_col8 {
#             background-color:  yellow;
#         }</style><table id="T_30ef48f8_419a_11e9_9e60_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >filters</th>        <th class="col_heading level0 col1" >strides</th>        <th class="col_heading level0 col2" >kernel_size</th>        <th class="col_heading level0 col3" >drop</th>        <th class="col_heading level0 col4" >full</th>        <th class="col_heading level0 col5" >fulldrop</th>        <th class="col_heading level0 col6" >lag</th>        <th class="col_heading level0 col7" >test</th>        <th class="col_heading level0 col8" >val</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
trace = []
for v in ['6', '12', '18', '24']:
    trace.append(go.Scatter(
        x = b[b['lag']==v]['test'],
        y = b[b['lag']==v]['val'],
        text='F-'+b[b['lag']==v]['full'].astype(str) + 'D-' + b[b['lag']==v]['drop'].astype(str) + '-L' + b[b['lag']==v]['lag'].astype(str)+ '-A' + b[b['lag']==v]['filters'].astype(str), 
        mode = 'markers', name=v
    ))
py.iplot(trace, filename='basic-scatter')
# Out:
# <div id="b743cbda-57d4-41d7-acf0-1d5dc931edbe" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b743cbda-57d4-41d7-acf0-1d5dc931edbe", [{"mode": "markers", "name": "6", "text": [], "x": [], "y": [], "type": "scatter", "uid": "a1873bec-ff32-43a8-a3e0-56af7357c36d"}, {"mode": "markers", "name": "12", "text": [], "x": [], "y": [], "type": "scatter", "uid": "7bbaf54a-a1ba-4e1d-9063-89198db012b4"}, {"mode": "markers", "name": "18", "text": ["F-[32]D-0.1-L18-A[128, 256]", "F-[32]D-0.1-L18-A[128, 256]", "F-[64]D-0.1-L18-A[128, 256]", "F-[64]D-0.1-L18-A[128, 256]", "F-[32]D-0.2-L18-A[128, 256]", "F-[32]D-0.2-L18-A[128, 256]", "F-[64]D-0.2-L18-A[128, 256]", "F-[64]D-0.2-L18-A[128, 256]", "F-[32]D-0.1-L18-A[256, 512]", "F-[32]D-0.1-L18-A[256, 512]", "F-[64]D-0.1-L18-A[256, 512]", "F-[64]D-0.1-L18-A[256, 512]"
# ...

# %% [markdown]
# Best Model CNN(256,512/1,1/7,5,0.2) FC(32,0) L(18)

# %% [markdown]
# ## Fit 6

# %%
query={'experiment':'cnns2sfit6'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()
results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop'], data=['lag'])

# %%
a=results.exp_df.groupby(['site','filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)

# %%
a.boxplot(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe663f30358>,
# ...
#       dtype=object)

# %%
b =a.groupby(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).mean()
b.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_39cfe7e8_419a_11e9_9e60_842b2bb021fdrow4_col7 {
#             background-color:  yellow;
#         }    #T_39cfe7e8_419a_11e9_9e60_842b2bb021fdrow4_col8 {
#             background-color:  yellow;
#         }</style><table id="T_39cfe7e8_419a_11e9_9e60_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >filters</th>        <th class="col_heading level0 col1" >strides</th>        <th class="col_heading level0 col2" >kernel_size</th>        <th class="col_heading level0 col3" >drop</th>        <th class="col_heading level0 col4" >full</th>        <th class="col_heading level0 col5" >fulldrop</th>        <th class="col_heading level0 col6" >lag</th>        <th class="col_heading level0 col7" >test</th>        <th class="col_heading level0 col8" >val</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
trace = []
for v in ['6', '12', '18', '24']:
    trace.append(go.Scatter(
        x = b[b['lag']==v]['test'],
        y = b[b['lag']==v]['val'],
        text='F-'+b[b['lag']==v]['full'].astype(str) + 'D-' + b[b['lag']==v]['drop'].astype(str) + '-L' + b[b['lag']==v]['lag'].astype(str)+ '-A' + b[b['lag']==v]['filters'].astype(str), 
        mode = 'markers', name=v
    ))
py.iplot(trace, filename='basic-scatter')
# Out:
# <div id="d8b4c999-73b7-470a-a223-a1010a3ad7a8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d8b4c999-73b7-470a-a223-a1010a3ad7a8", [{"mode": "markers", "name": "6", "text": [], "x": [], "y": [], "type": "scatter", "uid": "2b17167c-f7f7-4ad3-8097-52b6c9ed1bd5"}, {"mode": "markers", "name": "12", "text": [], "x": [], "y": [], "type": "scatter", "uid": "bcf3877a-ca28-4801-9a8e-d9b196f12a41"}, {"mode": "markers", "name": "18", "text": ["F-[32]D-0.0-L18-A[2048]", "F-[64]D-0.0-L18-A[2048]", "F-[32]D-0.1-L18-A[2048]", "F-[64]D-0.1-L18-A[2048]", "F-[32]D-0.2-L18-A[2048]", "F-[64]D-0.2-L18-A[2048]", "F-[32]D-0.0-L18-A[2048]", "F-[64]D-0.0-L18-A[2048]", "F-[32]D-0.1-L18-A[2048]", "F-[64]D-0.1-L18-A[2048]", "F-[32]D-0.2-L18-A[2048]", "F-[64]D-0.2-L18-A[2048]", "F-[32]D-0.0-L18-A[4096]", "F-[64]D-0.0-L18-A[
# ...

# %% [markdown]
# ## Fit 7

# %%
query={'experiment':'cnns2sfit7'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()
results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop'], data=['lag'])

# %%
a=results.exp_df.groupby(['site','filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)

# %%
a.boxplot(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe6567f40b8>,
# ...
#       dtype=object)

# %%
b =a.groupby(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).mean()
b.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_41910b10_419a_11e9_9e60_842b2bb021fdrow0_col7 {
#             background-color:  yellow;
#         }    #T_41910b10_419a_11e9_9e60_842b2bb021fdrow0_col8 {
#             background-color:  yellow;
#         }</style><table id="T_41910b10_419a_11e9_9e60_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >filters</th>        <th class="col_heading level0 col1" >strides</th>        <th class="col_heading level0 col2" >kernel_size</th>        <th class="col_heading level0 col3" >drop</th>        <th class="col_heading level0 col4" >full</th>        <th class="col_heading level0 col5" >fulldrop</th>        <th class="col_heading level0 col6" >lag</th>        <th class="col_heading level0 col7" >test</th>        <th class="col_heading level0 col8" >val</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
sns.kdeplot(b['test'],b['val'])

# %% [markdown]
# ## Fit 8

# %%
query={'experiment':'cnns2sfit8'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()
results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop', 'activation_full'], data=['lag'])

# %%
a=results.exp_df.groupby(['site','filters','strides','kernel_size','drop','full','fulldrop','lag', 'activation_full'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)
len(a)
# Out:
# 800

# %%
a.boxplot(by=['filters','strides','kernel_size','drop','full','fulldrop','lag', 'activation_full'],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe669e141d0>,
# ...
#       dtype=object)

# %%
b =a.groupby(by=['filters','strides','kernel_size','drop','full','fulldrop','lag', 'activation_full'],as_index=False).mean()
b.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_45b0ce6a_419a_11e9_9e60_842b2bb021fdrow1_col8 {
#             background-color:  yellow;
#         }    #T_45b0ce6a_419a_11e9_9e60_842b2bb021fdrow1_col9 {
#             background-color:  yellow;
#         }</style><table id="T_45b0ce6a_419a_11e9_9e60_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >filters</th>        <th class="col_heading level0 col1" >strides</th>        <th class="col_heading level0 col2" >kernel_size</th>        <th class="col_heading level0 col3" >drop</th>        <th class="col_heading level0 col4" >full</th>        <th class="col_heading level0 col5" >fulldrop</th>        <th class="col_heading level0 col6" >lag</th>        <th class="col_heading level0 col7" >activation_full</th>        <th class="col_heading level0 col8" >test</th>        <th class="col_heading level0 col9" >val</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
a.groupby(by=[ 'filters','strides','kernel_size','drop','full','fulldrop','lag', 'activation_full'],as_index=False).count()
# Out:
#   filters strides kernel_size drop  full fulldrop lag activation_full  test  \
# 0   [256]     [1]         [5]  0.2  [32]      0.0  18          linear   200
# 1   [256]     [1]         [5]  0.2  [32]      0.0  18            relu   200
# 2   [256]     [1]         [5]  0.2  [32]      0.0  18         sigmoid   200
# 3   [256]     [1]         [5]  0.2  [32]      0.0  18            tanh   200
#
#    val
# 0  200
# 1  200
# 2  200
# 3  200

# %%
sns.kdeplot(b['test'],b['val'])

# %% [markdown]
# ## Fit 9

# %%
query={'experiment':'cnns2sfit9'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()
results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop', 'activation_full', 'dilated'], data=['lag'])

# %%
a=results.exp_df.groupby(['site','filters','strides','kernel_size','drop','full','fulldrop','lag', 'activation_full', 'dilated'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)
len(a)
# Out:
# 21600

# %%
a.boxplot(by=['filters','strides','kernel_size','drop','full','fulldrop','lag', 'activation_full', 'dilated'],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe661a72668>,
# ...
#       dtype=object)

# %%
b =a.groupby(by=['filters','strides','kernel_size','drop','full','fulldrop','lag', 'activation_full', 'dilated'],as_index=False).mean()
b.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_541539a0_419a_11e9_9e60_842b2bb021fdrow102_col9 {
#             background-color:  yellow;
#         }    #T_541539a0_419a_11e9_9e60_842b2bb021fdrow102_col10 {
#             background-color:  yellow;
# ...

# %%
trace = []
for v in ['6', '12', '18', '24']:
    trace.append(go.Scatter(
        x = b[b['lag']==v]['test'],
        y = b[b['lag']==v]['val'],
        text='F-'+b[b['lag']==v]['full'].astype(str) + 'D-' + b[b['lag']==v]['drop'].astype(str) + '-L' + b[b['lag']==v]['lag'].astype(str)+ '-A' + b[b['lag']==v]['filters'].astype(str), 
        mode = 'markers', name=v
    ))
py.iplot(trace, filename='basic-scatter')
# Out:
# <div id="783e6016-9d3a-4c31-be95-abc885644b22" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("783e6016-9d3a-4c31-be95-abc885644b22", [{"mode": "markers", "name": "6", "text": [], "x": [], "y": [], "type": "scatter", "uid": "e201fe78-d3be-4554-9c65-4d42287c9505"}, {"mode": "markers", "name": "12", "text": [], "x": [], "y": [], "type": "scatter", "uid": "e6105c34-827c-4d62-a137-bb36388e5724"}, {"mode": "markers", "name": "18", "text": ["F-[32]D-0.1-L18-A[32]", "F-[32]D-0.2-L18-A[32]", "F-[32]D-0.1-L18-A[32]", "F-[32]D-0.2-L18-A[32]", "F-[32]D-0.1-L18-A[32]", "F-[32]D-0.2-L18-A[32]", "F-[32]D-0.1-L18-A[32]", "F-[32]D-0.2-L18-A[32]", "F-[32]D-0.1-L18-A[32]", "F-[32]D-0.2-L18-A[32]", "F-[32]D-0.1-L18-A[32]", "F-[32]D-0.2-L18-A[32]", "F-[32]D-0.1-L18-A[32]", "F-[32]D-0.2-L18-A[32]", "F-[32]D-0.1-L18-A[3
# ...

# %%
a.groupby(by=[ 'filters','strides','kernel_size','drop','full','fulldrop','lag', 'activation_full', 'dilated'],as_index=False).count()
# Out:
#     filters strides kernel_size drop  full fulldrop lag activation_full  \
# 0      [32]     [2]         [3]  0.1  [32]      0.0  18          linear
# 1      [32]     [2]         [3]  0.1  [32]      0.0  24          linear
# 2      [32]     [2]         [3]  0.1  [32]      0.0  30          linear
# 3      [32]     [2]         [3]  0.2  [32]      0.0  18          linear
# 4      [32]     [2]         [3]  0.2  [32]      0.0  24          linear
# 5      [32]     [2]         [3]  0.2  [32]      0.0  30          linear
# 6      [32]     [2]         [5]  0.1  [32]      0.0  18          linear
# 7      [32]     [2]         [5]  0.1  [32]      0.0  24          linear
# 8      [32]     [2]         [5]  0.1  [32]      0.0  30          linear
# 9      [32]     [2]         [5]  0.2  [32]      0.0  18          linear
# 10     [32]     [2]         [5]  0.2  [32]      0.0  24          linear
# 11     [32]     [2]         [5]  0.2  [32]      0.0  30          linear
# ...

# %% [markdown]
# ## Fit 10 (exponential dilated)

# %%
query={'experiment':'cnns2sfitdil1'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()
results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop', 'activation_full', 'dilated'], data=['lag'])

# %%
a=results.exp_df.groupby(['site','filters','strides','kernel_size','drop','full','fulldrop','lag', 'activation_full', 'dilated'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)
len(a)
# Out:
# 28797

# %%
a[a['lag']=='18'].boxplot(by=['filters','strides','kernel_size','drop','full','fulldrop','lag', 'activation_full', 'dilated'],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe661b744e0>,
# ...
#       dtype=object)

# %%
b =a.groupby(by=['filters','strides','kernel_size','drop','full','fulldrop','lag', 'activation_full', 'dilated'],as_index=False).mean()
b.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_a0b05b0e_419b_11e9_9e60_842b2bb021fdrow121_col9 {
#             background-color:  yellow;
#         }    #T_a0b05b0e_419b_11e9_9e60_842b2bb021fdrow121_col10 {
#             background-color:  yellow;
# ...

# %%
trace = []
for v in ['6', '12', '18', '24']:
    trace.append(go.Scatter(
        x = b[b['lag']==v]['test'],
        y = b[b['lag']==v]['val'],
        text='F-'+b[b['lag']==v]['full'].astype(str) + 'D-' + b[b['lag']==v]['drop'].astype(str) + '-L' + b[b['lag']==v]['lag'].astype(str)+ '-A' + b[b['lag']==v]['filters'].astype(str), 
        mode = 'markers', name=v
    ))
py.iplot(trace, filename='basic-scatter')
# Out:
# <div id="59affe34-81e1-4815-92d1-84553fdbdf3e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("59affe34-81e1-4815-92d1-84553fdbdf3e", [{"mode": "markers", "name": "6", "text": [], "x": [], "y": [], "type": "scatter", "uid": "ef7e74a9-bd1b-4df7-81a0-5114e8056e79"}, {"mode": "markers", "name": "12", "text": ["F-[32]D-0.0-L12-A[32, 32, 32]", "F-[64]D-0.0-L12-A[32, 32, 32]", "F-[32]D-0.1-L12-A[32, 32, 32]", "F-[64]D-0.1-L12-A[32, 32, 32]"], "x": [5.138670662680786, 5.1242286544599995, 5.322698713388138, 5.327106619735307], "y": [4.748893132225732, 4.7373123674274575, 4.982482474378667, 4.9756975524436], "type": "scatter", "uid": "1b6e7afc-7566-421b-9c58-2c20dc1174d4"}, {"mode": "markers", "name": "18", "text": ["F-[128]D-0.0-L18-A[128, 128, 128]", "F-[32]D-0.0-L18-A[128, 128, 128]", "F-[64, 32]D-0.0-L1
# ...

# %%
a[a['lag']=='18'].groupby(by=[ 'filters','strides','kernel_size','drop','full','fulldrop','lag', 'activation_full', 'dilated'],as_index=False).count()
# Out:
#              filters    strides kernel_size drop      full fulldrop lag  \
# 0    [128, 128, 128]  [1, 2, 4]   [3, 3, 3]  0.0     [128]      0.0  18
# 1    [128, 128, 128]  [1, 2, 4]   [3, 3, 3]  0.0      [32]      0.0  18
# 2    [128, 128, 128]  [1, 2, 4]   [3, 3, 3]  0.0  [64, 32]      0.0  18
# 3    [128, 128, 128]  [1, 2, 4]   [3, 3, 3]  0.0      [64]      0.0  18
# 4    [128, 128, 128]  [1, 2, 4]   [5, 5, 5]  0.0     [128]      0.0  18
# 5    [128, 128, 128]  [1, 2, 4]   [5, 5, 5]  0.0      [32]      0.0  18
# 6    [128, 128, 128]  [1, 2, 4]   [5, 5, 5]  0.0  [64, 32]      0.0  18
# 7    [128, 128, 128]  [1, 2, 4]   [5, 5, 5]  0.0      [64]      0.0  18
# 8    [128, 128, 128]  [1, 2, 4]   [7, 7, 7]  0.0     [128]      0.0  18
# 9    [128, 128, 128]  [1, 2, 4]   [7, 7, 7]  0.0      [32]      0.0  18
# 10   [128, 128, 128]  [1, 2, 4]   [7, 7, 7]  0.0  [64, 32]      0.0  18
# 11   [128, 128, 128]  [1, 2, 4]   [7, 7, 7]  0.0      [64]      0.0  18
# ...

# %% [markdown]
# ## Fit 11 (Leaky Relu/ELU)

# %%
query={'experiment':'cnns2sleakyelu'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()
results.results_dataframe_retrieve(query, arch=['filters','strides','kernel_size','drop','full','fulldrop', 'activation_full'], data=['lag'])

# %%
results.results_dataframe_aggregate(threshold=7.02)
# Out:
# <style  type="text/css" >
#     #T_bc2e258a_5c4b_11e9_a029_842b2bb021fdrow0_col9 {
#             background-color:  yellow;
#         }    #T_bc2e258a_5c4b_11e9_a029_842b2bb021fdrow1_col9 {
#             background-color:  yellow;
#         }    #T_bc2e258a_5c4b_11e9_a029_842b2bb021fdrow2_col9 {
#             background-color:  yellow;
#         }    #T_bc2e258a_5c4b_11e9_a029_842b2bb021fdrow2_col10 {
#             background-color:  yellow;
#         }    #T_bc2e258a_5c4b_11e9_a029_842b2bb021fdrow3_col9 {
#             background-color:  yellow;
#         }    #T_bc2e258a_5c4b_11e9_a029_842b2bb021fdrow4_col9 {
#             background-color:  yellow;
#         }    #T_bc2e258a_5c4b_11e9_a029_842b2bb021fdrow5_col8 {
#             background-color:  yellow;
#         }    #T_bc2e258a_5c4b_11e9_a029_842b2bb021fdrow5_col9 {
#             background-color:  yellow;
#         }    #T_bc2e258a_5c4b_11e9_a029_842b2bb021fdrow6_col9 {
#             background-color:  yellow;
# ...

# %%
results.results_dataframe_graph(facet='fulldrop',att=['filters','strides','kernel_size','drop','full','fulldrop', 'activation_full','lag'])
# Out:
# <div id="98d40b82-e645-4e7a-a991-669288674759" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("98d40b82-e645-4e7a-a991-669288674759")) {
# ...

# %% [markdown]
# # Fit Bayesian

# %%
query={'experiment':'cnns2ssmac'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()
results.results_dataframe_retrieve(query, arch=['filters','strides','kernel_size','drop','full','fulldrop', 'activation_full', 'activation'], data=['lag'])

# %%
results.results_dataframe_aggregate(threshold=6.8)
# Out:
# 358
# <style  type="text/css" >
#     #T_38ffeb18_65b9_11e9_aeed_842b2bb021fdrow3_col10 {
#             background-color:  yellow;
#         }    #T_38ffeb18_65b9_11e9_aeed_842b2bb021fdrow6_col9 {
#             background-color:  yellow;
#         }    #T_38ffeb18_65b9_11e9_aeed_842b2bb021fdrow6_col11 {
#             background-color:  yellow;
# ...

# %%
results.results_dataframe_graph(facet='fulldrop',att=['filters','strides','kernel_size','drop','full','fulldrop', 'activation_full','lag'])
# Out:
# <div id="ed53d2b4-9615-4075-b6cc-a8979cc87656" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("ed53d2b4-9615-4075-b6cc-a8979cc87656")) {
# ...
