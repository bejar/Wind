# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Wind.Results import DBResults
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import seaborn as sns
from Wind.Private.DBConfig import mongolocaltest, mongolocal
import matplotlib.pyplot as plt
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # Fitting CNN s2s

# %% [markdown]
# ## Fit1

# %%
query={'experiment':'cnns2sfit'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()

results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop'], data=['lag'])

# %%
a=results.exp_df.groupby(['site','filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)

# %%
a[a['lag']=='12'].boxplot(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],figsize=(20,10), rot=90)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f30366ca6d8>,
# ...
#       dtype=object)

# %%
b =a.groupby(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).mean()
b.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_6d87efca_2518_11e9_947e_842b2bb021fdrow253_col7 {
#             background-color:  yellow;
#         }    #T_6d87efca_2518_11e9_947e_842b2bb021fdrow253_col8 {
#             background-color:  yellow;
#         }</style><table id="T_6d87efca_2518_11e9_947e_842b2bb021fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >filters</th>        <th class="col_heading level0 col1" >strides</th>        <th class="col_heading level0 col2" >kernel_size</th>        <th class="col_heading level0 col3" >drop</th>        <th class="col_heading level0 col4" >full</th>        <th class="col_heading level0 col5" >fulldrop</th>        <th class="col_heading level0 col6" >lag</th>        <th class="col_heading level0 col7" >test</th>        <th class="col_heading level0 col8" >val</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# Best model CNN(64/1/5,0.1) FC(64,0) L(18)

# %% [markdown]
# ## Fit 2

# %%
query={'experiment':'cnns2sfit2'}

results = DBResults(conn=mongolocaltest)
#results = DBResults()

results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop'], data=['lag'])
results.size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-55527866a8d0> in <module>
#       5
#       6 results.retrieve_results_dataframe(query, arch=['filters','strides','kernel_size','drop','full','fulldrop'], data=['lag'])
# ----> 7 results.size()
#       8
#
# ~/PycharmProjects/Wind/Wind/Results/DBResults.py in size(self)
#     359         """
#     360         if not self.exp_result and self.exp_df is not None:
# --> 361             raise NameError("No results yet retrieved")
#     362
#     363         if self.exp_result:
#
# NameError: No results yet retrieved

# %%
a=results.exp_df.groupby(['site','filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).sum()
a.drop(columns=['hour', 'site'], inplace=True)

# %%
a[a['lag']=='18'].boxplot(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],figsize=(20,10), rot=90)

# %%
b =a.groupby(by=['filters','strides','kernel_size','drop','full','fulldrop','lag'],as_index=False).mean()
b.style.highlight_max()
