# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('result-11-5794.txt', delimiter=',')
df.describe()
# Out:
#            DATAS  VARS        LAG      AHEAD  NLAY  NNEUR          DROP  \
# count  95.000000  95.0  95.000000  95.000000  95.0   95.0  9.500000e+01
# mean    1.989474   6.0  14.905263   6.442105   2.0   32.0  5.000000e-02
# std     1.005249   0.0   6.714661   3.441659   0.0    0.0  9.765987e-17
# min     1.000000   6.0   6.000000   1.000000   2.0   32.0  5.000000e-02
# 25%     1.000000   6.0   9.000000   3.500000   2.0   32.0  5.000000e-02
# 50%     1.000000   6.0  12.000000   6.000000   2.0   32.0  5.000000e-02
# 75%     3.000000   6.0  18.000000   9.000000   2.0   32.0  5.000000e-02
# max     3.000000   6.0  24.000000  12.000000   2.0   32.0  5.000000e-02
#
#            R2Val    R2persV     R2Test    R2persT
# count  95.000000  95.000000  95.000000  95.000000
# mean    0.584889  -0.069338   0.542165  -0.036866
# std     0.153538   0.552186   0.174504   0.523609
# min     0.409050  -0.783260   0.346270  -0.715870
# 25%     0.456220  -0.547200   0.395775  -0.479110
# ...

# %%
plt.plot(range(1,13), df[(df['DATAS'] == 1) & (df['LAG'] == 6)]['R2Val'], color='r')
plt.plot(range(1,13), df[(df['DATAS'] == 1) & (df['LAG'] == 24)]['R2Val'], color='b')
